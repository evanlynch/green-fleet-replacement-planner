# %%
import gurobipy as grb
import numpy as np

# %% [markdown]
# #### Notes
# - dummy costs are just completely random numbers for now. Will need to replace with functions that can project out throguh the planning period

# %% [markdown]
# # Data

# %%
#random set of vehicles. v_p (v prime) is the set of ICE vehicles. v_pp (v double prime) is the set of EV alternatives
V_P = ['FORD FOCUS','DODGE JOURNEY','HONDA CR-V']
V_PP = ['FORD FUSION HYBRID','CHRYSLER PACIFICA HYBRID','HONDA CR-V HYBRID']
V = V_P+V_PP

print(f'ICEs: {V_P}')
print(f'EVs: {V_PP}')
print(f'All: {V}')
# Out:
# ICEs: ['FORD FOCUS', 'DODGE JOURNEY', 'HONDA CR-V']
# EVs: ['FORD FUSION HYBRID', 'CHRYSLER PACIFICA HYBRID', 'HONDA CR-V HYBRID']
# All: ['FORD FOCUS', 'DODGE JOURNEY', 'HONDA CR-V', 'FORD FUSION HYBRID', 'CHRYSLER PACIFICA HYBRID', 'HONDA CR-V HYBRID']

# %%
#random set of departments
D = ['County Sheriff',
     "State's Attorney",
     'Housing Services']
D
# Out:
# ['County Sheriff', "State's Attorney", 'Housing Services']

# %%
#years in the planning horizon
T = [t for t in range(2021,2038)]
T
# Out:
# [2021,
#  2022,
#  2023,
#  2024,
#  2025,
#  2026,
#  2027,
#  2028,
#  2029,
#  2030,
#  2031,
#  2032,
#  2033,
#  2034,
#  2035,
#  2036,
#  2037]

# %%
#generate random inventory
I = {}
for d in D:
    for v_p in V_P:
        I[v_p,d] = np.random.randint(20,70)
    for v_pp in V_PP:
        I[v_pp,d] = 0
I
# Out:
# {('FORD FOCUS', 'County Sheriff'): 67,
#  ('DODGE JOURNEY', 'County Sheriff'): 60,
#  ('HONDA CR-V', 'County Sheriff'): 37,
#  ('FORD FUSION HYBRID', 'County Sheriff'): 0,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff'): 0,
#  ('HONDA CR-V HYBRID', 'County Sheriff'): 0,
#  ('FORD FOCUS', "State's Attorney"): 40,
#  ('DODGE JOURNEY', "State's Attorney"): 64,
#  ('HONDA CR-V', "State's Attorney"): 28,
#  ('FORD FUSION HYBRID', "State's Attorney"): 0,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney"): 0,
#  ('HONDA CR-V HYBRID', "State's Attorney"): 0,
#  ('FORD FOCUS', 'Housing Services'): 35,
#  ('DODGE JOURNEY', 'Housing Services'): 68,
#  ('HONDA CR-V', 'Housing Services'): 59,
#  ('FORD FUSION HYBRID', 'Housing Services'): 0,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services'): 0,
#  ('HONDA CR-V HYBRID', 'Housing Services'): 0}

# %%
#cost factors for consumables (C), maintenance (M), and VMT
dimensions,C,M,VMT = grb.multidict({(v,d,t): [np.random.randint(1,4), #random consumables cost per mile 
                             np.random.randint(200,400), #random maintenance cost per vehicle
                             np.random.randint(10000,20000),] #random VMT 
                            for v in V for d in D for t in T
                  })

# %%
C
# Out:
# {('FORD FOCUS', 'County Sheriff', 2021): 1,
#  ('FORD FOCUS', 'County Sheriff', 2022): 1,
#  ('FORD FOCUS', 'County Sheriff', 2023): 3,
#  ('FORD FOCUS', 'County Sheriff', 2024): 1,
#  ('FORD FOCUS', 'County Sheriff', 2025): 1,
#  ('FORD FOCUS', 'County Sheriff', 2026): 1,
#  ('FORD FOCUS', 'County Sheriff', 2027): 3,
#  ('FORD FOCUS', 'County Sheriff', 2028): 1,
#  ('FORD FOCUS', 'County Sheriff', 2029): 1,
#  ('FORD FOCUS', 'County Sheriff', 2030): 3,
#  ('FORD FOCUS', 'County Sheriff', 2031): 1,
#  ('FORD FOCUS', 'County Sheriff', 2032): 3,
#  ('FORD FOCUS', 'County Sheriff', 2033): 1,
#  ('FORD FOCUS', 'County Sheriff', 2034): 1,
#  ('FORD FOCUS', 'County Sheriff', 2035): 1,
#  ('FORD FOCUS', 'County Sheriff', 2036): 2,
#  ('FORD FOCUS', 'County Sheriff', 2037): 1,
#  ('FORD FOCUS', "State's Attorney", 2021): 1,
#  ('FORD FOCUS', "State's Attorney", 2022): 3,
#  ('FORD FOCUS', "State's Attorney", 2023): 3,
#  ('FORD FOCUS', "State's Attorney", 2024): 2,
#  ('FORD FOCUS', "State's Attorney", 2025): 1,
#  ('FORD FOCUS', "State's Attorney", 2026): 1,
#  ('FORD FOCUS', "State's Attorney", 2027): 3,
#  ('FORD FOCUS', "State's Attorney", 2028): 1,
#  ('FORD FOCUS', "State's Attorney", 2029): 1,
#  ('FORD FOCUS', "State's Attorney", 2030): 1,
#  ('FORD FOCUS', "State's Attorney", 2031): 2,
#  ('FORD FOCUS', "State's Attorney", 2032): 1,
#  ('FORD FOCUS', "State's Attorney", 2033): 3,
#  ('FORD FOCUS', "State's Attorney", 2034): 1,
#  ('FORD FOCUS', "State's Attorney", 2035): 1,
#  ('FORD FOCUS', "State's Attorney", 2036): 3,
#  ('FORD FOCUS', "State's Attorney", 2037): 2,
#  ('FORD FOCUS', 'Housing Services', 2021): 1,
#  ('FORD FOCUS', 'Housing Services', 2022): 2,
#  ('FORD FOCUS', 'Housing Services', 2023): 1,
#  ('FORD FOCUS', 'Housing Services', 2024): 2,
#  ('FORD FOCUS', 'Housing Services', 2025): 1,
#  ('FORD FOCUS', 'Housing Services', 2026): 1,
#  ('FORD FOCUS', 'Housing Services', 2027): 3,
#  ('FORD FOCUS', 'Housing Services', 2028): 1,
#  ('FORD FOCUS', 'Housing Services', 2029): 1,
#  ('FORD FOCUS', 'Housing Services', 2030): 3,
#  ('FORD FOCUS', 'Housing Services', 2031): 2,
#  ('FORD FOCUS', 'Housing Services', 2032): 1,
#  ('FORD FOCUS', 'Housing Services', 2033): 2,
#  ('FORD FOCUS', 'Housing Services', 2034): 2,
#  ('FORD FOCUS', 'Housing Services', 2035): 1,
#  ('FORD FOCUS', 'Housing Services', 2036): 3,
#  ('FORD FOCUS', 'Housing Services', 2037): 2,
#  ('DODGE JOURNEY', 'County Sheriff', 2021): 2,
#  ('DODGE JOURNEY', 'County Sheriff', 2022): 3,
#  ('DODGE JOURNEY', 'County Sheriff', 2023): 1,
#  ('DODGE JOURNEY', 'County Sheriff', 2024): 2,
#  ('DODGE JOURNEY', 'County Sheriff', 2025): 3,
#  ('DODGE JOURNEY', 'County Sheriff', 2026): 2,
#  ('DODGE JOURNEY', 'County Sheriff', 2027): 3,
#  ('DODGE JOURNEY', 'County Sheriff', 2028): 2,
#  ('DODGE JOURNEY', 'County Sheriff', 2029): 1,
#  ('DODGE JOURNEY', 'County Sheriff', 2030): 3,
#  ('DODGE JOURNEY', 'County Sheriff', 2031): 2,
#  ('DODGE JOURNEY', 'County Sheriff', 2032): 1,
#  ('DODGE JOURNEY', 'County Sheriff', 2033): 2,
#  ('DODGE JOURNEY', 'County Sheriff', 2034): 2,
#  ('DODGE JOURNEY', 'County Sheriff', 2035): 2,
#  ('DODGE JOURNEY', 'County Sheriff', 2036): 2,
#  ('DODGE JOURNEY', 'County Sheriff', 2037): 3,
#  ('DODGE JOURNEY', "State's Attorney", 2021): 1,
#  ('DODGE JOURNEY', "State's Attorney", 2022): 3,
#  ('DODGE JOURNEY', "State's Attorney", 2023): 3,
#  ('DODGE JOURNEY', "State's Attorney", 2024): 1,
#  ('DODGE JOURNEY', "State's Attorney", 2025): 3,
#  ('DODGE JOURNEY', "State's Attorney", 2026): 3,
#  ('DODGE JOURNEY', "State's Attorney", 2027): 1,
#  ('DODGE JOURNEY', "State's Attorney", 2028): 2,
#  ('DODGE JOURNEY', "State's Attorney", 2029): 1,
#  ('DODGE JOURNEY', "State's Attorney", 2030): 2,
#  ('DODGE JOURNEY', "State's Attorney", 2031): 3,
#  ('DODGE JOURNEY', "State's Attorney", 2032): 2,
#  ('DODGE JOURNEY', "State's Attorney", 2033): 3,
#  ('DODGE JOURNEY', "State's Attorney", 2034): 3,
#  ('DODGE JOURNEY', "State's Attorney", 2035): 3,
#  ('DODGE JOURNEY', "State's Attorney", 2036): 1,
#  ('DODGE JOURNEY', "State's Attorney", 2037): 3,
#  ('DODGE JOURNEY', 'Housing Services', 2021): 1,
#  ('DODGE JOURNEY', 'Housing Services', 2022): 3,
#  ('DODGE JOURNEY', 'Housing Services', 2023): 3,
#  ('DODGE JOURNEY', 'Housing Services', 2024): 1,
#  ('DODGE JOURNEY', 'Housing Services', 2025): 3,
#  ('DODGE JOURNEY', 'Housing Services', 2026): 3,
#  ('DODGE JOURNEY', 'Housing Services', 2027): 3,
#  ('DODGE JOURNEY', 'Housing Services', 2028): 3,
#  ('DODGE JOURNEY', 'Housing Services', 2029): 3,
#  ('DODGE JOURNEY', 'Housing Services', 2030): 2,
#  ('DODGE JOURNEY', 'Housing Services', 2031): 3,
#  ('DODGE JOURNEY', 'Housing Services', 2032): 1,
#  ('DODGE JOURNEY', 'Housing Services', 2033): 3,
#  ('DODGE JOURNEY', 'Housing Services', 2034): 3,
#  ('DODGE JOURNEY', 'Housing Services', 2035): 1,
#  ('DODGE JOURNEY', 'Housing Services', 2036): 3,
#  ('DODGE JOURNEY', 'Housing Services', 2037): 2,
#  ('HONDA CR-V', 'County Sheriff', 2021): 1,
#  ('HONDA CR-V', 'County Sheriff', 2022): 2,
#  ('HONDA CR-V', 'County Sheriff', 2023): 3,
#  ('HONDA CR-V', 'County Sheriff', 2024): 2,
#  ('HONDA CR-V', 'County Sheriff', 2025): 2,
#  ('HONDA CR-V', 'County Sheriff', 2026): 3,
#  ('HONDA CR-V', 'County Sheriff', 2027): 3,
#  ('HONDA CR-V', 'County Sheriff', 2028): 2,
#  ('HONDA CR-V', 'County Sheriff', 2029): 2,
#  ('HONDA CR-V', 'County Sheriff', 2030): 1,
#  ('HONDA CR-V', 'County Sheriff', 2031): 3,
#  ('HONDA CR-V', 'County Sheriff', 2032): 3,
#  ('HONDA CR-V', 'County Sheriff', 2033): 3,
#  ('HONDA CR-V', 'County Sheriff', 2034): 3,
#  ('HONDA CR-V', 'County Sheriff', 2035): 1,
#  ('HONDA CR-V', 'County Sheriff', 2036): 3,
#  ('HONDA CR-V', 'County Sheriff', 2037): 3,
#  ('HONDA CR-V', "State's Attorney", 2021): 3,
#  ('HONDA CR-V', "State's Attorney", 2022): 2,
#  ('HONDA CR-V', "State's Attorney", 2023): 3,
#  ('HONDA CR-V', "State's Attorney", 2024): 1,
#  ('HONDA CR-V', "State's Attorney", 2025): 1,
#  ('HONDA CR-V', "State's Attorney", 2026): 3,
#  ('HONDA CR-V', "State's Attorney", 2027): 2,
#  ('HONDA CR-V', "State's Attorney", 2028): 3,
#  ('HONDA CR-V', "State's Attorney", 2029): 3,
#  ('HONDA CR-V', "State's Attorney", 2030): 3,
#  ('HONDA CR-V', "State's Attorney", 2031): 2,
#  ('HONDA CR-V', "State's Attorney", 2032): 2,
#  ('HONDA CR-V', "State's Attorney", 2033): 1,
#  ('HONDA CR-V', "State's Attorney", 2034): 2,
#  ('HONDA CR-V', "State's Attorney", 2035): 1,
#  ('HONDA CR-V', "State's Attorney", 2036): 3,
#  ('HONDA CR-V', "State's Attorney", 2037): 1,
#  ('HONDA CR-V', 'Housing Services', 2021): 2,
#  ('HONDA CR-V', 'Housing Services', 2022): 1,
#  ('HONDA CR-V', 'Housing Services', 2023): 1,
#  ('HONDA CR-V', 'Housing Services', 2024): 2,
#  ('HONDA CR-V', 'Housing Services', 2025): 3,
#  ('HONDA CR-V', 'Housing Services', 2026): 1,
#  ('HONDA CR-V', 'Housing Services', 2027): 3,
#  ('HONDA CR-V', 'Housing Services', 2028): 2,
#  ('HONDA CR-V', 'Housing Services', 2029): 1,
#  ('HONDA CR-V', 'Housing Services', 2030): 1,
#  ('HONDA CR-V', 'Housing Services', 2031): 1,
#  ('HONDA CR-V', 'Housing Services', 2032): 1,
#  ('HONDA CR-V', 'Housing Services', 2033): 2,
#  ('HONDA CR-V', 'Housing Services', 2034): 3,
#  ('HONDA CR-V', 'Housing Services', 2035): 3,
#  ('HONDA CR-V', 'Housing Services', 2036): 1,
#  ('HONDA CR-V', 'Housing Services', 2037): 3,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2021): 3,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2022): 3,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2023): 2,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2024): 3,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2025): 3,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2026): 2,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2027): 3,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2028): 2,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2029): 2,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2030): 2,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2031): 2,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2032): 1,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2033): 2,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2034): 2,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2035): 2,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2036): 1,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2037): 2,
#  ('FORD FUSION HYBRID', "State's Attorney", 2021): 2,
#  ('FORD FUSION HYBRID', "State's Attorney", 2022): 2,
#  ('FORD FUSION HYBRID', "State's Attorney", 2023): 2,
#  ('FORD FUSION HYBRID', "State's Attorney", 2024): 1,
#  ('FORD FUSION HYBRID', "State's Attorney", 2025): 1,
#  ('FORD FUSION HYBRID', "State's Attorney", 2026): 2,
#  ('FORD FUSION HYBRID', "State's Attorney", 2027): 3,
#  ('FORD FUSION HYBRID', "State's Attorney", 2028): 3,
#  ('FORD FUSION HYBRID', "State's Attorney", 2029): 3,
#  ('FORD FUSION HYBRID', "State's Attorney", 2030): 2,
#  ('FORD FUSION HYBRID', "State's Attorney", 2031): 1,
#  ('FORD FUSION HYBRID', "State's Attorney", 2032): 2,
#  ('FORD FUSION HYBRID', "State's Attorney", 2033): 2,
#  ('FORD FUSION HYBRID', "State's Attorney", 2034): 1,
#  ('FORD FUSION HYBRID', "State's Attorney", 2035): 3,
#  ('FORD FUSION HYBRID', "State's Attorney", 2036): 3,
#  ('FORD FUSION HYBRID', "State's Attorney", 2037): 1,
#  ('FORD FUSION HYBRID', 'Housing Services', 2021): 2,
#  ('FORD FUSION HYBRID', 'Housing Services', 2022): 2,
#  ('FORD FUSION HYBRID', 'Housing Services', 2023): 3,
#  ('FORD FUSION HYBRID', 'Housing Services', 2024): 1,
#  ('FORD FUSION HYBRID', 'Housing Services', 2025): 2,
#  ('FORD FUSION HYBRID', 'Housing Services', 2026): 1,
#  ('FORD FUSION HYBRID', 'Housing Services', 2027): 2,
#  ('FORD FUSION HYBRID', 'Housing Services', 2028): 2,
#  ('FORD FUSION HYBRID', 'Housing Services', 2029): 3,
#  ('FORD FUSION HYBRID', 'Housing Services', 2030): 2,
#  ('FORD FUSION HYBRID', 'Housing Services', 2031): 3,
#  ('FORD FUSION HYBRID', 'Housing Services', 2032): 2,
#  ('FORD FUSION HYBRID', 'Housing Services', 2033): 3,
#  ('FORD FUSION HYBRID', 'Housing Services', 2034): 1,
#  ('FORD FUSION HYBRID', 'Housing Services', 2035): 1,
#  ('FORD FUSION HYBRID', 'Housing Services', 2036): 2,
#  ('FORD FUSION HYBRID', 'Housing Services', 2037): 3,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2021): 1,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2022): 3,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2023): 2,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2024): 3,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2025): 2,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2026): 1,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2027): 1,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2028): 3,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2029): 2,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2030): 3,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2031): 1,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2032): 1,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2033): 2,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2034): 3,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2035): 2,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2036): 2,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2037): 3,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2021): 2,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2022): 1,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2023): 2,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2024): 1,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2025): 2,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2026): 1,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2027): 2,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2028): 2,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2029): 3,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2030): 2,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2031): 1,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2032): 1,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2033): 1,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2034): 2,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2035): 1,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2036): 1,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2037): 3,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2021): 3,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2022): 2,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2023): 3,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2024): 1,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2025): 1,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2026): 3,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2027): 1,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2028): 3,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2029): 1,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2030): 2,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2031): 2,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2032): 3,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2033): 2,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2034): 2,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2035): 3,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2036): 1,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2037): 1,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2021): 3,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2022): 2,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2023): 1,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2024): 1,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2025): 2,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2026): 3,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2027): 2,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2028): 2,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2029): 3,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2030): 2,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2031): 3,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2032): 3,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2033): 2,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2034): 1,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2035): 3,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2036): 1,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2037): 2,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2021): 3,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2022): 1,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2023): 1,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2024): 3,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2025): 2,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2026): 2,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2027): 3,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2028): 1,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2029): 1,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2030): 2,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2031): 2,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2032): 2,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2033): 2,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2034): 3,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2035): 2,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2036): 3,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2037): 3,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2021): 1,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2022): 2,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2023): 1,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2024): 2,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2025): 3,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2026): 3,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2027): 3,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2028): 1,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2029): 3,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2030): 3,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2031): 3,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2032): 1,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2033): 3,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2034): 3,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2035): 1,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2036): 1,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2037): 3}

# %%
M
# Out:
# {('FORD FOCUS', 'County Sheriff', 2021): 398,
#  ('FORD FOCUS', 'County Sheriff', 2022): 213,
#  ('FORD FOCUS', 'County Sheriff', 2023): 209,
#  ('FORD FOCUS', 'County Sheriff', 2024): 296,
#  ('FORD FOCUS', 'County Sheriff', 2025): 254,
#  ('FORD FOCUS', 'County Sheriff', 2026): 394,
#  ('FORD FOCUS', 'County Sheriff', 2027): 245,
#  ('FORD FOCUS', 'County Sheriff', 2028): 352,
#  ('FORD FOCUS', 'County Sheriff', 2029): 294,
#  ('FORD FOCUS', 'County Sheriff', 2030): 221,
#  ('FORD FOCUS', 'County Sheriff', 2031): 300,
#  ('FORD FOCUS', 'County Sheriff', 2032): 346,
#  ('FORD FOCUS', 'County Sheriff', 2033): 302,
#  ('FORD FOCUS', 'County Sheriff', 2034): 311,
#  ('FORD FOCUS', 'County Sheriff', 2035): 281,
#  ('FORD FOCUS', 'County Sheriff', 2036): 312,
#  ('FORD FOCUS', 'County Sheriff', 2037): 378,
#  ('FORD FOCUS', "State's Attorney", 2021): 376,
#  ('FORD FOCUS', "State's Attorney", 2022): 342,
#  ('FORD FOCUS', "State's Attorney", 2023): 239,
#  ('FORD FOCUS', "State's Attorney", 2024): 205,
#  ('FORD FOCUS', "State's Attorney", 2025): 267,
#  ('FORD FOCUS', "State's Attorney", 2026): 313,
#  ('FORD FOCUS', "State's Attorney", 2027): 277,
#  ('FORD FOCUS', "State's Attorney", 2028): 390,
#  ('FORD FOCUS', "State's Attorney", 2029): 294,
#  ('FORD FOCUS', "State's Attorney", 2030): 372,
#  ('FORD FOCUS', "State's Attorney", 2031): 252,
#  ('FORD FOCUS', "State's Attorney", 2032): 217,
#  ('FORD FOCUS', "State's Attorney", 2033): 202,
#  ('FORD FOCUS', "State's Attorney", 2034): 310,
#  ('FORD FOCUS', "State's Attorney", 2035): 385,
#  ('FORD FOCUS', "State's Attorney", 2036): 346,
#  ('FORD FOCUS', "State's Attorney", 2037): 281,
#  ('FORD FOCUS', 'Housing Services', 2021): 221,
#  ('FORD FOCUS', 'Housing Services', 2022): 234,
#  ('FORD FOCUS', 'Housing Services', 2023): 246,
#  ('FORD FOCUS', 'Housing Services', 2024): 304,
#  ('FORD FOCUS', 'Housing Services', 2025): 339,
#  ('FORD FOCUS', 'Housing Services', 2026): 371,
#  ('FORD FOCUS', 'Housing Services', 2027): 386,
#  ('FORD FOCUS', 'Housing Services', 2028): 245,
#  ('FORD FOCUS', 'Housing Services', 2029): 319,
#  ('FORD FOCUS', 'Housing Services', 2030): 282,
#  ('FORD FOCUS', 'Housing Services', 2031): 377,
#  ('FORD FOCUS', 'Housing Services', 2032): 251,
#  ('FORD FOCUS', 'Housing Services', 2033): 227,
#  ('FORD FOCUS', 'Housing Services', 2034): 250,
#  ('FORD FOCUS', 'Housing Services', 2035): 390,
#  ('FORD FOCUS', 'Housing Services', 2036): 228,
#  ('FORD FOCUS', 'Housing Services', 2037): 247,
#  ('DODGE JOURNEY', 'County Sheriff', 2021): 284,
#  ('DODGE JOURNEY', 'County Sheriff', 2022): 325,
#  ('DODGE JOURNEY', 'County Sheriff', 2023): 259,
#  ('DODGE JOURNEY', 'County Sheriff', 2024): 345,
#  ('DODGE JOURNEY', 'County Sheriff', 2025): 395,
#  ('DODGE JOURNEY', 'County Sheriff', 2026): 353,
#  ('DODGE JOURNEY', 'County Sheriff', 2027): 376,
#  ('DODGE JOURNEY', 'County Sheriff', 2028): 234,
#  ('DODGE JOURNEY', 'County Sheriff', 2029): 311,
#  ('DODGE JOURNEY', 'County Sheriff', 2030): 270,
#  ('DODGE JOURNEY', 'County Sheriff', 2031): 379,
#  ('DODGE JOURNEY', 'County Sheriff', 2032): 347,
#  ('DODGE JOURNEY', 'County Sheriff', 2033): 283,
#  ('DODGE JOURNEY', 'County Sheriff', 2034): 345,
#  ('DODGE JOURNEY', 'County Sheriff', 2035): 250,
#  ('DODGE JOURNEY', 'County Sheriff', 2036): 316,
#  ('DODGE JOURNEY', 'County Sheriff', 2037): 214,
#  ('DODGE JOURNEY', "State's Attorney", 2021): 393,
#  ('DODGE JOURNEY', "State's Attorney", 2022): 362,
#  ('DODGE JOURNEY', "State's Attorney", 2023): 235,
#  ('DODGE JOURNEY', "State's Attorney", 2024): 390,
#  ('DODGE JOURNEY', "State's Attorney", 2025): 328,
#  ('DODGE JOURNEY', "State's Attorney", 2026): 293,
#  ('DODGE JOURNEY', "State's Attorney", 2027): 311,
#  ('DODGE JOURNEY', "State's Attorney", 2028): 335,
#  ('DODGE JOURNEY', "State's Attorney", 2029): 286,
#  ('DODGE JOURNEY', "State's Attorney", 2030): 236,
#  ('DODGE JOURNEY', "State's Attorney", 2031): 273,
#  ('DODGE JOURNEY', "State's Attorney", 2032): 370,
#  ('DODGE JOURNEY', "State's Attorney", 2033): 257,
#  ('DODGE JOURNEY', "State's Attorney", 2034): 374,
#  ('DODGE JOURNEY', "State's Attorney", 2035): 382,
#  ('DODGE JOURNEY', "State's Attorney", 2036): 302,
#  ('DODGE JOURNEY', "State's Attorney", 2037): 345,
#  ('DODGE JOURNEY', 'Housing Services', 2021): 357,
#  ('DODGE JOURNEY', 'Housing Services', 2022): 298,
#  ('DODGE JOURNEY', 'Housing Services', 2023): 317,
#  ('DODGE JOURNEY', 'Housing Services', 2024): 336,
#  ('DODGE JOURNEY', 'Housing Services', 2025): 289,
#  ('DODGE JOURNEY', 'Housing Services', 2026): 393,
#  ('DODGE JOURNEY', 'Housing Services', 2027): 294,
#  ('DODGE JOURNEY', 'Housing Services', 2028): 330,
#  ('DODGE JOURNEY', 'Housing Services', 2029): 242,
#  ('DODGE JOURNEY', 'Housing Services', 2030): 213,
#  ('DODGE JOURNEY', 'Housing Services', 2031): 235,
#  ('DODGE JOURNEY', 'Housing Services', 2032): 291,
#  ('DODGE JOURNEY', 'Housing Services', 2033): 376,
#  ('DODGE JOURNEY', 'Housing Services', 2034): 231,
#  ('DODGE JOURNEY', 'Housing Services', 2035): 215,
#  ('DODGE JOURNEY', 'Housing Services', 2036): 217,
#  ('DODGE JOURNEY', 'Housing Services', 2037): 391,
#  ('HONDA CR-V', 'County Sheriff', 2021): 274,
#  ('HONDA CR-V', 'County Sheriff', 2022): 387,
#  ('HONDA CR-V', 'County Sheriff', 2023): 284,
#  ('HONDA CR-V', 'County Sheriff', 2024): 333,
#  ('HONDA CR-V', 'County Sheriff', 2025): 284,
#  ('HONDA CR-V', 'County Sheriff', 2026): 399,
#  ('HONDA CR-V', 'County Sheriff', 2027): 205,
#  ('HONDA CR-V', 'County Sheriff', 2028): 209,
#  ('HONDA CR-V', 'County Sheriff', 2029): 388,
#  ('HONDA CR-V', 'County Sheriff', 2030): 225,
#  ('HONDA CR-V', 'County Sheriff', 2031): 218,
#  ('HONDA CR-V', 'County Sheriff', 2032): 328,
#  ('HONDA CR-V', 'County Sheriff', 2033): 379,
#  ('HONDA CR-V', 'County Sheriff', 2034): 287,
#  ('HONDA CR-V', 'County Sheriff', 2035): 239,
#  ('HONDA CR-V', 'County Sheriff', 2036): 323,
#  ('HONDA CR-V', 'County Sheriff', 2037): 214,
#  ('HONDA CR-V', "State's Attorney", 2021): 386,
#  ('HONDA CR-V', "State's Attorney", 2022): 249,
#  ('HONDA CR-V', "State's Attorney", 2023): 381,
#  ('HONDA CR-V', "State's Attorney", 2024): 344,
#  ('HONDA CR-V', "State's Attorney", 2025): 233,
#  ('HONDA CR-V', "State's Attorney", 2026): 281,
#  ('HONDA CR-V', "State's Attorney", 2027): 339,
#  ('HONDA CR-V', "State's Attorney", 2028): 343,
#  ('HONDA CR-V', "State's Attorney", 2029): 212,
#  ('HONDA CR-V', "State's Attorney", 2030): 224,
#  ('HONDA CR-V', "State's Attorney", 2031): 282,
#  ('HONDA CR-V', "State's Attorney", 2032): 266,
#  ('HONDA CR-V', "State's Attorney", 2033): 244,
#  ('HONDA CR-V', "State's Attorney", 2034): 376,
#  ('HONDA CR-V', "State's Attorney", 2035): 310,
#  ('HONDA CR-V', "State's Attorney", 2036): 391,
#  ('HONDA CR-V', "State's Attorney", 2037): 225,
#  ('HONDA CR-V', 'Housing Services', 2021): 204,
#  ('HONDA CR-V', 'Housing Services', 2022): 302,
#  ('HONDA CR-V', 'Housing Services', 2023): 239,
#  ('HONDA CR-V', 'Housing Services', 2024): 349,
#  ('HONDA CR-V', 'Housing Services', 2025): 291,
#  ('HONDA CR-V', 'Housing Services', 2026): 203,
#  ('HONDA CR-V', 'Housing Services', 2027): 347,
#  ('HONDA CR-V', 'Housing Services', 2028): 273,
#  ('HONDA CR-V', 'Housing Services', 2029): 243,
#  ('HONDA CR-V', 'Housing Services', 2030): 306,
#  ('HONDA CR-V', 'Housing Services', 2031): 373,
#  ('HONDA CR-V', 'Housing Services', 2032): 383,
#  ('HONDA CR-V', 'Housing Services', 2033): 386,
#  ('HONDA CR-V', 'Housing Services', 2034): 267,
#  ('HONDA CR-V', 'Housing Services', 2035): 341,
#  ('HONDA CR-V', 'Housing Services', 2036): 233,
#  ('HONDA CR-V', 'Housing Services', 2037): 381,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2021): 344,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2022): 224,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2023): 203,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2024): 395,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2025): 235,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2026): 251,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2027): 273,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2028): 272,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2029): 346,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2030): 293,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2031): 273,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2032): 362,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2033): 338,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2034): 300,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2035): 295,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2036): 396,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2037): 397,
#  ('FORD FUSION HYBRID', "State's Attorney", 2021): 359,
#  ('FORD FUSION HYBRID', "State's Attorney", 2022): 393,
#  ('FORD FUSION HYBRID', "State's Attorney", 2023): 282,
#  ('FORD FUSION HYBRID', "State's Attorney", 2024): 336,
#  ('FORD FUSION HYBRID', "State's Attorney", 2025): 268,
#  ('FORD FUSION HYBRID', "State's Attorney", 2026): 206,
#  ('FORD FUSION HYBRID', "State's Attorney", 2027): 396,
#  ('FORD FUSION HYBRID', "State's Attorney", 2028): 368,
#  ('FORD FUSION HYBRID', "State's Attorney", 2029): 303,
#  ('FORD FUSION HYBRID', "State's Attorney", 2030): 346,
#  ('FORD FUSION HYBRID', "State's Attorney", 2031): 326,
#  ('FORD FUSION HYBRID', "State's Attorney", 2032): 368,
#  ('FORD FUSION HYBRID', "State's Attorney", 2033): 375,
#  ('FORD FUSION HYBRID', "State's Attorney", 2034): 291,
#  ('FORD FUSION HYBRID', "State's Attorney", 2035): 375,
#  ('FORD FUSION HYBRID', "State's Attorney", 2036): 354,
#  ('FORD FUSION HYBRID', "State's Attorney", 2037): 339,
#  ('FORD FUSION HYBRID', 'Housing Services', 2021): 269,
#  ('FORD FUSION HYBRID', 'Housing Services', 2022): 312,
#  ('FORD FUSION HYBRID', 'Housing Services', 2023): 302,
#  ('FORD FUSION HYBRID', 'Housing Services', 2024): 219,
#  ('FORD FUSION HYBRID', 'Housing Services', 2025): 302,
#  ('FORD FUSION HYBRID', 'Housing Services', 2026): 281,
#  ('FORD FUSION HYBRID', 'Housing Services', 2027): 246,
#  ('FORD FUSION HYBRID', 'Housing Services', 2028): 336,
#  ('FORD FUSION HYBRID', 'Housing Services', 2029): 333,
#  ('FORD FUSION HYBRID', 'Housing Services', 2030): 296,
#  ('FORD FUSION HYBRID', 'Housing Services', 2031): 380,
#  ('FORD FUSION HYBRID', 'Housing Services', 2032): 357,
#  ('FORD FUSION HYBRID', 'Housing Services', 2033): 245,
#  ('FORD FUSION HYBRID', 'Housing Services', 2034): 230,
#  ('FORD FUSION HYBRID', 'Housing Services', 2035): 275,
#  ('FORD FUSION HYBRID', 'Housing Services', 2036): 247,
#  ('FORD FUSION HYBRID', 'Housing Services', 2037): 247,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2021): 227,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2022): 314,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2023): 253,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2024): 204,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2025): 274,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2026): 363,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2027): 260,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2028): 305,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2029): 287,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2030): 363,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2031): 332,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2032): 357,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2033): 374,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2034): 369,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2035): 317,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2036): 219,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2037): 298,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2021): 292,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2022): 249,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2023): 264,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2024): 299,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2025): 390,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2026): 202,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2027): 223,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2028): 203,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2029): 305,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2030): 303,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2031): 294,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2032): 304,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2033): 211,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2034): 308,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2035): 399,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2036): 397,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2037): 279,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2021): 280,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2022): 372,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2023): 241,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2024): 279,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2025): 234,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2026): 228,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2027): 259,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2028): 305,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2029): 233,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2030): 258,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2031): 361,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2032): 235,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2033): 219,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2034): 351,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2035): 286,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2036): 364,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2037): 288,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2021): 256,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2022): 203,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2023): 226,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2024): 373,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2025): 282,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2026): 330,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2027): 372,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2028): 260,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2029): 298,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2030): 297,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2031): 203,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2032): 278,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2033): 300,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2034): 323,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2035): 348,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2036): 252,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2037): 386,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2021): 289,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2022): 378,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2023): 289,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2024): 207,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2025): 259,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2026): 306,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2027): 274,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2028): 324,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2029): 306,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2030): 260,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2031): 308,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2032): 268,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2033): 223,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2034): 398,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2035): 339,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2036): 248,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2037): 203,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2021): 361,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2022): 296,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2023): 284,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2024): 248,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2025): 320,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2026): 252,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2027): 366,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2028): 375,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2029): 352,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2030): 387,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2031): 206,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2032): 228,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2033): 394,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2034): 252,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2035): 322,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2036): 255,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2037): 388}

# %%
VMT
# Out:
# {('FORD FOCUS', 'County Sheriff', 2021): 11500,
#  ('FORD FOCUS', 'County Sheriff', 2022): 12507,
#  ('FORD FOCUS', 'County Sheriff', 2023): 13658,
#  ('FORD FOCUS', 'County Sheriff', 2024): 14010,
#  ('FORD FOCUS', 'County Sheriff', 2025): 16300,
#  ('FORD FOCUS', 'County Sheriff', 2026): 16888,
#  ('FORD FOCUS', 'County Sheriff', 2027): 17026,
#  ('FORD FOCUS', 'County Sheriff', 2028): 18654,
#  ('FORD FOCUS', 'County Sheriff', 2029): 10154,
#  ('FORD FOCUS', 'County Sheriff', 2030): 16815,
#  ('FORD FOCUS', 'County Sheriff', 2031): 11521,
#  ('FORD FOCUS', 'County Sheriff', 2032): 12704,
#  ('FORD FOCUS', 'County Sheriff', 2033): 11839,
#  ('FORD FOCUS', 'County Sheriff', 2034): 17679,
#  ('FORD FOCUS', 'County Sheriff', 2035): 10689,
#  ('FORD FOCUS', 'County Sheriff', 2036): 12510,
#  ('FORD FOCUS', 'County Sheriff', 2037): 15566,
#  ('FORD FOCUS', "State's Attorney", 2021): 10646,
#  ('FORD FOCUS', "State's Attorney", 2022): 17181,
#  ('FORD FOCUS', "State's Attorney", 2023): 14843,
#  ('FORD FOCUS', "State's Attorney", 2024): 17769,
#  ('FORD FOCUS', "State's Attorney", 2025): 16856,
#  ('FORD FOCUS', "State's Attorney", 2026): 18380,
#  ('FORD FOCUS', "State's Attorney", 2027): 12630,
#  ('FORD FOCUS', "State's Attorney", 2028): 11949,
#  ('FORD FOCUS', "State's Attorney", 2029): 13338,
#  ('FORD FOCUS', "State's Attorney", 2030): 10166,
#  ('FORD FOCUS', "State's Attorney", 2031): 15356,
#  ('FORD FOCUS', "State's Attorney", 2032): 13673,
#  ('FORD FOCUS', "State's Attorney", 2033): 16537,
#  ('FORD FOCUS', "State's Attorney", 2034): 19059,
#  ('FORD FOCUS', "State's Attorney", 2035): 17865,
#  ('FORD FOCUS', "State's Attorney", 2036): 12337,
#  ('FORD FOCUS', "State's Attorney", 2037): 11395,
#  ('FORD FOCUS', 'Housing Services', 2021): 10839,
#  ('FORD FOCUS', 'Housing Services', 2022): 11115,
#  ('FORD FOCUS', 'Housing Services', 2023): 14086,
#  ('FORD FOCUS', 'Housing Services', 2024): 16082,
#  ('FORD FOCUS', 'Housing Services', 2025): 13990,
#  ('FORD FOCUS', 'Housing Services', 2026): 18987,
#  ('FORD FOCUS', 'Housing Services', 2027): 12101,
#  ('FORD FOCUS', 'Housing Services', 2028): 18874,
#  ('FORD FOCUS', 'Housing Services', 2029): 19993,
#  ('FORD FOCUS', 'Housing Services', 2030): 12042,
#  ('FORD FOCUS', 'Housing Services', 2031): 14179,
#  ('FORD FOCUS', 'Housing Services', 2032): 16689,
#  ('FORD FOCUS', 'Housing Services', 2033): 15608,
#  ('FORD FOCUS', 'Housing Services', 2034): 16142,
#  ('FORD FOCUS', 'Housing Services', 2035): 19341,
#  ('FORD FOCUS', 'Housing Services', 2036): 10411,
#  ('FORD FOCUS', 'Housing Services', 2037): 17372,
#  ('DODGE JOURNEY', 'County Sheriff', 2021): 15430,
#  ('DODGE JOURNEY', 'County Sheriff', 2022): 16561,
#  ('DODGE JOURNEY', 'County Sheriff', 2023): 15489,
#  ('DODGE JOURNEY', 'County Sheriff', 2024): 11471,
#  ('DODGE JOURNEY', 'County Sheriff', 2025): 11393,
#  ('DODGE JOURNEY', 'County Sheriff', 2026): 10428,
#  ('DODGE JOURNEY', 'County Sheriff', 2027): 16783,
#  ('DODGE JOURNEY', 'County Sheriff', 2028): 16615,
#  ('DODGE JOURNEY', 'County Sheriff', 2029): 18203,
#  ('DODGE JOURNEY', 'County Sheriff', 2030): 15553,
#  ('DODGE JOURNEY', 'County Sheriff', 2031): 16729,
#  ('DODGE JOURNEY', 'County Sheriff', 2032): 18894,
#  ('DODGE JOURNEY', 'County Sheriff', 2033): 11078,
#  ('DODGE JOURNEY', 'County Sheriff', 2034): 18523,
#  ('DODGE JOURNEY', 'County Sheriff', 2035): 11787,
#  ('DODGE JOURNEY', 'County Sheriff', 2036): 14349,
#  ('DODGE JOURNEY', 'County Sheriff', 2037): 18712,
#  ('DODGE JOURNEY', "State's Attorney", 2021): 16112,
#  ('DODGE JOURNEY', "State's Attorney", 2022): 11800,
#  ('DODGE JOURNEY', "State's Attorney", 2023): 17739,
#  ('DODGE JOURNEY', "State's Attorney", 2024): 19564,
#  ('DODGE JOURNEY', "State's Attorney", 2025): 10116,
#  ('DODGE JOURNEY', "State's Attorney", 2026): 13957,
#  ('DODGE JOURNEY', "State's Attorney", 2027): 14912,
#  ('DODGE JOURNEY', "State's Attorney", 2028): 10486,
#  ('DODGE JOURNEY', "State's Attorney", 2029): 10839,
#  ('DODGE JOURNEY', "State's Attorney", 2030): 16512,
#  ('DODGE JOURNEY', "State's Attorney", 2031): 17863,
#  ('DODGE JOURNEY', "State's Attorney", 2032): 12944,
#  ('DODGE JOURNEY', "State's Attorney", 2033): 19712,
#  ('DODGE JOURNEY', "State's Attorney", 2034): 19583,
#  ('DODGE JOURNEY', "State's Attorney", 2035): 11523,
#  ('DODGE JOURNEY', "State's Attorney", 2036): 15477,
#  ('DODGE JOURNEY', "State's Attorney", 2037): 12765,
#  ('DODGE JOURNEY', 'Housing Services', 2021): 14452,
#  ('DODGE JOURNEY', 'Housing Services', 2022): 18496,
#  ('DODGE JOURNEY', 'Housing Services', 2023): 17221,
#  ('DODGE JOURNEY', 'Housing Services', 2024): 19595,
#  ('DODGE JOURNEY', 'Housing Services', 2025): 18523,
#  ('DODGE JOURNEY', 'Housing Services', 2026): 10116,
#  ('DODGE JOURNEY', 'Housing Services', 2027): 15482,
#  ('DODGE JOURNEY', 'Housing Services', 2028): 15822,
#  ('DODGE JOURNEY', 'Housing Services', 2029): 15660,
#  ('DODGE JOURNEY', 'Housing Services', 2030): 15511,
#  ('DODGE JOURNEY', 'Housing Services', 2031): 11250,
#  ('DODGE JOURNEY', 'Housing Services', 2032): 15054,
#  ('DODGE JOURNEY', 'Housing Services', 2033): 10968,
#  ('DODGE JOURNEY', 'Housing Services', 2034): 12234,
#  ('DODGE JOURNEY', 'Housing Services', 2035): 14578,
#  ('DODGE JOURNEY', 'Housing Services', 2036): 19822,
#  ('DODGE JOURNEY', 'Housing Services', 2037): 10263,
#  ('HONDA CR-V', 'County Sheriff', 2021): 10452,
#  ('HONDA CR-V', 'County Sheriff', 2022): 10641,
#  ('HONDA CR-V', 'County Sheriff', 2023): 10197,
#  ('HONDA CR-V', 'County Sheriff', 2024): 14259,
#  ('HONDA CR-V', 'County Sheriff', 2025): 10940,
#  ('HONDA CR-V', 'County Sheriff', 2026): 15634,
#  ('HONDA CR-V', 'County Sheriff', 2027): 11905,
#  ('HONDA CR-V', 'County Sheriff', 2028): 19322,
#  ('HONDA CR-V', 'County Sheriff', 2029): 19814,
#  ('HONDA CR-V', 'County Sheriff', 2030): 11039,
#  ('HONDA CR-V', 'County Sheriff', 2031): 18247,
#  ('HONDA CR-V', 'County Sheriff', 2032): 12615,
#  ('HONDA CR-V', 'County Sheriff', 2033): 18854,
#  ('HONDA CR-V', 'County Sheriff', 2034): 12417,
#  ('HONDA CR-V', 'County Sheriff', 2035): 13272,
#  ('HONDA CR-V', 'County Sheriff', 2036): 19935,
#  ('HONDA CR-V', 'County Sheriff', 2037): 16364,
#  ('HONDA CR-V', "State's Attorney", 2021): 16857,
#  ('HONDA CR-V', "State's Attorney", 2022): 18088,
#  ('HONDA CR-V', "State's Attorney", 2023): 15630,
#  ('HONDA CR-V', "State's Attorney", 2024): 16511,
#  ('HONDA CR-V', "State's Attorney", 2025): 18354,
#  ('HONDA CR-V', "State's Attorney", 2026): 10886,
#  ('HONDA CR-V', "State's Attorney", 2027): 14245,
#  ('HONDA CR-V', "State's Attorney", 2028): 14116,
#  ('HONDA CR-V', "State's Attorney", 2029): 19056,
#  ('HONDA CR-V', "State's Attorney", 2030): 15376,
#  ('HONDA CR-V', "State's Attorney", 2031): 16394,
#  ('HONDA CR-V', "State's Attorney", 2032): 11516,
#  ('HONDA CR-V', "State's Attorney", 2033): 13670,
#  ('HONDA CR-V', "State's Attorney", 2034): 12249,
#  ('HONDA CR-V', "State's Attorney", 2035): 14484,
#  ('HONDA CR-V', "State's Attorney", 2036): 16255,
#  ('HONDA CR-V', "State's Attorney", 2037): 19719,
#  ('HONDA CR-V', 'Housing Services', 2021): 13005,
#  ('HONDA CR-V', 'Housing Services', 2022): 16836,
#  ('HONDA CR-V', 'Housing Services', 2023): 12751,
#  ('HONDA CR-V', 'Housing Services', 2024): 15759,
#  ('HONDA CR-V', 'Housing Services', 2025): 17694,
#  ('HONDA CR-V', 'Housing Services', 2026): 10630,
#  ('HONDA CR-V', 'Housing Services', 2027): 19932,
#  ('HONDA CR-V', 'Housing Services', 2028): 15391,
#  ('HONDA CR-V', 'Housing Services', 2029): 17842,
#  ('HONDA CR-V', 'Housing Services', 2030): 18687,
#  ('HONDA CR-V', 'Housing Services', 2031): 17511,
#  ('HONDA CR-V', 'Housing Services', 2032): 19326,
#  ('HONDA CR-V', 'Housing Services', 2033): 10667,
#  ('HONDA CR-V', 'Housing Services', 2034): 19656,
#  ('HONDA CR-V', 'Housing Services', 2035): 18594,
#  ('HONDA CR-V', 'Housing Services', 2036): 10421,
#  ('HONDA CR-V', 'Housing Services', 2037): 15891,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2021): 14793,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2022): 19188,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2023): 14925,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2024): 19806,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2025): 12800,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2026): 16456,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2027): 19717,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2028): 15463,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2029): 16043,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2030): 11463,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2031): 13883,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2032): 10933,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2033): 10889,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2034): 18630,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2035): 17393,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2036): 17383,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2037): 18070,
#  ('FORD FUSION HYBRID', "State's Attorney", 2021): 10778,
#  ('FORD FUSION HYBRID', "State's Attorney", 2022): 12696,
#  ('FORD FUSION HYBRID', "State's Attorney", 2023): 17110,
#  ('FORD FUSION HYBRID', "State's Attorney", 2024): 12012,
#  ('FORD FUSION HYBRID', "State's Attorney", 2025): 18007,
#  ('FORD FUSION HYBRID', "State's Attorney", 2026): 16475,
#  ('FORD FUSION HYBRID', "State's Attorney", 2027): 18833,
#  ('FORD FUSION HYBRID', "State's Attorney", 2028): 12421,
#  ('FORD FUSION HYBRID', "State's Attorney", 2029): 10085,
#  ('FORD FUSION HYBRID', "State's Attorney", 2030): 11428,
#  ('FORD FUSION HYBRID', "State's Attorney", 2031): 13764,
#  ('FORD FUSION HYBRID', "State's Attorney", 2032): 12865,
#  ('FORD FUSION HYBRID', "State's Attorney", 2033): 12134,
#  ('FORD FUSION HYBRID', "State's Attorney", 2034): 11466,
#  ('FORD FUSION HYBRID', "State's Attorney", 2035): 13534,
#  ('FORD FUSION HYBRID', "State's Attorney", 2036): 11963,
#  ('FORD FUSION HYBRID', "State's Attorney", 2037): 12035,
#  ('FORD FUSION HYBRID', 'Housing Services', 2021): 18887,
#  ('FORD FUSION HYBRID', 'Housing Services', 2022): 13326,
#  ('FORD FUSION HYBRID', 'Housing Services', 2023): 18038,
#  ('FORD FUSION HYBRID', 'Housing Services', 2024): 11925,
#  ('FORD FUSION HYBRID', 'Housing Services', 2025): 19769,
#  ('FORD FUSION HYBRID', 'Housing Services', 2026): 15163,
#  ('FORD FUSION HYBRID', 'Housing Services', 2027): 11439,
#  ('FORD FUSION HYBRID', 'Housing Services', 2028): 12912,
#  ('FORD FUSION HYBRID', 'Housing Services', 2029): 14147,
#  ('FORD FUSION HYBRID', 'Housing Services', 2030): 16116,
#  ('FORD FUSION HYBRID', 'Housing Services', 2031): 14578,
#  ('FORD FUSION HYBRID', 'Housing Services', 2032): 13536,
#  ('FORD FUSION HYBRID', 'Housing Services', 2033): 17148,
#  ('FORD FUSION HYBRID', 'Housing Services', 2034): 19786,
#  ('FORD FUSION HYBRID', 'Housing Services', 2035): 11760,
#  ('FORD FUSION HYBRID', 'Housing Services', 2036): 13370,
#  ('FORD FUSION HYBRID', 'Housing Services', 2037): 16113,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2021): 10863,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2022): 12781,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2023): 19759,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2024): 17650,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2025): 12148,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2026): 10282,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2027): 17836,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2028): 16160,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2029): 17633,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2030): 15445,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2031): 18448,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2032): 12291,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2033): 12610,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2034): 19380,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2035): 13840,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2036): 10236,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2037): 12106,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2021): 15875,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2022): 19521,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2023): 17433,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2024): 18096,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2025): 18173,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2026): 12582,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2027): 17157,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2028): 15759,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2029): 18259,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2030): 19487,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2031): 19949,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2032): 12757,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2033): 10501,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2034): 13150,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2035): 16757,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2036): 15592,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2037): 18367,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2021): 19165,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2022): 11443,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2023): 11815,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2024): 11251,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2025): 11187,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2026): 18666,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2027): 13639,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2028): 10535,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2029): 12550,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2030): 13388,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2031): 17917,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2032): 16222,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2033): 17206,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2034): 16966,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2035): 19729,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2036): 15504,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2037): 16143,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2021): 10822,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2022): 12916,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2023): 18233,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2024): 14884,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2025): 16706,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2026): 15257,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2027): 11522,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2028): 15320,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2029): 15249,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2030): 14116,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2031): 14532,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2032): 17955,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2033): 13970,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2034): 17027,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2035): 18884,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2036): 12831,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2037): 19285,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2021): 17262,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2022): 14825,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2023): 18396,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2024): 12609,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2025): 11720,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2026): 11921,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2027): 17964,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2028): 19819,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2029): 16176,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2030): 16699,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2031): 19668,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2032): 19482,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2033): 19910,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2034): 10583,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2035): 16144,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2036): 18891,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2037): 17768,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2021): 11138,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2022): 15358,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2023): 12165,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2024): 10451,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2025): 15920,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2026): 18326,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2027): 18531,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2028): 16260,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2029): 15779,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2030): 16982,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2031): 13206,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2032): 19452,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2033): 13149,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2034): 17760,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2035): 12167,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2036): 10485,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2037): 10137}

# %%
#miles per gallon (fuel efficiency) for each ICE
MPG = {v_p:np.random.randint(20,30) for v_p in V_P}

# %%
#estimated emissions for each vehicle in V_P. Currently putting 0 for V_PP
E = {(v_p,d,t) : round(VMT[(v_p,d,t)]/MPG[v_p]) for v_p in V_P for d in D for t in T}
E.update({(v_pp,d,t) : 0 for v_pp in V_PP for d in D for t in T})
E
# Out:
# {('FORD FOCUS', 'County Sheriff', 2021): 575,
#  ('FORD FOCUS', 'County Sheriff', 2022): 625,
#  ('FORD FOCUS', 'County Sheriff', 2023): 683,
#  ('FORD FOCUS', 'County Sheriff', 2024): 700,
#  ('FORD FOCUS', 'County Sheriff', 2025): 815,
#  ('FORD FOCUS', 'County Sheriff', 2026): 844,
#  ('FORD FOCUS', 'County Sheriff', 2027): 851,
#  ('FORD FOCUS', 'County Sheriff', 2028): 933,
#  ('FORD FOCUS', 'County Sheriff', 2029): 508,
#  ('FORD FOCUS', 'County Sheriff', 2030): 841,
#  ('FORD FOCUS', 'County Sheriff', 2031): 576,
#  ('FORD FOCUS', 'County Sheriff', 2032): 635,
#  ('FORD FOCUS', 'County Sheriff', 2033): 592,
#  ('FORD FOCUS', 'County Sheriff', 2034): 884,
#  ('FORD FOCUS', 'County Sheriff', 2035): 534,
#  ('FORD FOCUS', 'County Sheriff', 2036): 626,
#  ('FORD FOCUS', 'County Sheriff', 2037): 778,
#  ('FORD FOCUS', "State's Attorney", 2021): 532,
#  ('FORD FOCUS', "State's Attorney", 2022): 859,
#  ('FORD FOCUS', "State's Attorney", 2023): 742,
#  ('FORD FOCUS', "State's Attorney", 2024): 888,
#  ('FORD FOCUS', "State's Attorney", 2025): 843,
#  ('FORD FOCUS', "State's Attorney", 2026): 919,
#  ('FORD FOCUS', "State's Attorney", 2027): 632,
#  ('FORD FOCUS', "State's Attorney", 2028): 597,
#  ('FORD FOCUS', "State's Attorney", 2029): 667,
#  ('FORD FOCUS', "State's Attorney", 2030): 508,
#  ('FORD FOCUS', "State's Attorney", 2031): 768,
#  ('FORD FOCUS', "State's Attorney", 2032): 684,
#  ('FORD FOCUS', "State's Attorney", 2033): 827,
#  ('FORD FOCUS', "State's Attorney", 2034): 953,
#  ('FORD FOCUS', "State's Attorney", 2035): 893,
#  ('FORD FOCUS', "State's Attorney", 2036): 617,
#  ('FORD FOCUS', "State's Attorney", 2037): 570,
#  ('FORD FOCUS', 'Housing Services', 2021): 542,
#  ('FORD FOCUS', 'Housing Services', 2022): 556,
#  ('FORD FOCUS', 'Housing Services', 2023): 704,
#  ('FORD FOCUS', 'Housing Services', 2024): 804,
#  ('FORD FOCUS', 'Housing Services', 2025): 700,
#  ('FORD FOCUS', 'Housing Services', 2026): 949,
#  ('FORD FOCUS', 'Housing Services', 2027): 605,
#  ('FORD FOCUS', 'Housing Services', 2028): 944,
#  ('FORD FOCUS', 'Housing Services', 2029): 1000,
#  ('FORD FOCUS', 'Housing Services', 2030): 602,
#  ('FORD FOCUS', 'Housing Services', 2031): 709,
#  ('FORD FOCUS', 'Housing Services', 2032): 834,
#  ('FORD FOCUS', 'Housing Services', 2033): 780,
#  ('FORD FOCUS', 'Housing Services', 2034): 807,
#  ('FORD FOCUS', 'Housing Services', 2035): 967,
#  ('FORD FOCUS', 'Housing Services', 2036): 521,
#  ('FORD FOCUS', 'Housing Services', 2037): 869,
#  ('DODGE JOURNEY', 'County Sheriff', 2021): 772,
#  ('DODGE JOURNEY', 'County Sheriff', 2022): 828,
#  ('DODGE JOURNEY', 'County Sheriff', 2023): 774,
#  ('DODGE JOURNEY', 'County Sheriff', 2024): 574,
#  ('DODGE JOURNEY', 'County Sheriff', 2025): 570,
#  ('DODGE JOURNEY', 'County Sheriff', 2026): 521,
#  ('DODGE JOURNEY', 'County Sheriff', 2027): 839,
#  ('DODGE JOURNEY', 'County Sheriff', 2028): 831,
#  ('DODGE JOURNEY', 'County Sheriff', 2029): 910,
#  ('DODGE JOURNEY', 'County Sheriff', 2030): 778,
#  ('DODGE JOURNEY', 'County Sheriff', 2031): 836,
#  ('DODGE JOURNEY', 'County Sheriff', 2032): 945,
#  ('DODGE JOURNEY', 'County Sheriff', 2033): 554,
#  ('DODGE JOURNEY', 'County Sheriff', 2034): 926,
#  ('DODGE JOURNEY', 'County Sheriff', 2035): 589,
#  ('DODGE JOURNEY', 'County Sheriff', 2036): 717,
#  ('DODGE JOURNEY', 'County Sheriff', 2037): 936,
#  ('DODGE JOURNEY', "State's Attorney", 2021): 806,
#  ('DODGE JOURNEY', "State's Attorney", 2022): 590,
#  ('DODGE JOURNEY', "State's Attorney", 2023): 887,
#  ('DODGE JOURNEY', "State's Attorney", 2024): 978,
#  ('DODGE JOURNEY', "State's Attorney", 2025): 506,
#  ('DODGE JOURNEY', "State's Attorney", 2026): 698,
#  ('DODGE JOURNEY', "State's Attorney", 2027): 746,
#  ('DODGE JOURNEY', "State's Attorney", 2028): 524,
#  ('DODGE JOURNEY', "State's Attorney", 2029): 542,
#  ('DODGE JOURNEY', "State's Attorney", 2030): 826,
#  ('DODGE JOURNEY', "State's Attorney", 2031): 893,
#  ('DODGE JOURNEY', "State's Attorney", 2032): 647,
#  ('DODGE JOURNEY', "State's Attorney", 2033): 986,
#  ('DODGE JOURNEY', "State's Attorney", 2034): 979,
#  ('DODGE JOURNEY', "State's Attorney", 2035): 576,
#  ('DODGE JOURNEY', "State's Attorney", 2036): 774,
#  ('DODGE JOURNEY', "State's Attorney", 2037): 638,
#  ('DODGE JOURNEY', 'Housing Services', 2021): 723,
#  ('DODGE JOURNEY', 'Housing Services', 2022): 925,
#  ('DODGE JOURNEY', 'Housing Services', 2023): 861,
#  ('DODGE JOURNEY', 'Housing Services', 2024): 980,
#  ('DODGE JOURNEY', 'Housing Services', 2025): 926,
#  ('DODGE JOURNEY', 'Housing Services', 2026): 506,
#  ('DODGE JOURNEY', 'Housing Services', 2027): 774,
#  ('DODGE JOURNEY', 'Housing Services', 2028): 791,
#  ('DODGE JOURNEY', 'Housing Services', 2029): 783,
#  ('DODGE JOURNEY', 'Housing Services', 2030): 776,
#  ('DODGE JOURNEY', 'Housing Services', 2031): 562,
#  ('DODGE JOURNEY', 'Housing Services', 2032): 753,
#  ('DODGE JOURNEY', 'Housing Services', 2033): 548,
#  ('DODGE JOURNEY', 'Housing Services', 2034): 612,
#  ('DODGE JOURNEY', 'Housing Services', 2035): 729,
#  ('DODGE JOURNEY', 'Housing Services', 2036): 991,
#  ('DODGE JOURNEY', 'Housing Services', 2037): 513,
#  ('HONDA CR-V', 'County Sheriff', 2021): 373,
#  ('HONDA CR-V', 'County Sheriff', 2022): 380,
#  ('HONDA CR-V', 'County Sheriff', 2023): 364,
#  ('HONDA CR-V', 'County Sheriff', 2024): 509,
#  ('HONDA CR-V', 'County Sheriff', 2025): 391,
#  ('HONDA CR-V', 'County Sheriff', 2026): 558,
#  ('HONDA CR-V', 'County Sheriff', 2027): 425,
#  ('HONDA CR-V', 'County Sheriff', 2028): 690,
#  ('HONDA CR-V', 'County Sheriff', 2029): 708,
#  ('HONDA CR-V', 'County Sheriff', 2030): 394,
#  ('HONDA CR-V', 'County Sheriff', 2031): 652,
#  ('HONDA CR-V', 'County Sheriff', 2032): 451,
#  ('HONDA CR-V', 'County Sheriff', 2033): 673,
#  ('HONDA CR-V', 'County Sheriff', 2034): 443,
#  ('HONDA CR-V', 'County Sheriff', 2035): 474,
#  ('HONDA CR-V', 'County Sheriff', 2036): 712,
#  ('HONDA CR-V', 'County Sheriff', 2037): 584,
#  ('HONDA CR-V', "State's Attorney", 2021): 602,
#  ('HONDA CR-V', "State's Attorney", 2022): 646,
#  ('HONDA CR-V', "State's Attorney", 2023): 558,
#  ('HONDA CR-V', "State's Attorney", 2024): 590,
#  ('HONDA CR-V', "State's Attorney", 2025): 656,
#  ('HONDA CR-V', "State's Attorney", 2026): 389,
#  ('HONDA CR-V', "State's Attorney", 2027): 509,
#  ('HONDA CR-V', "State's Attorney", 2028): 504,
#  ('HONDA CR-V', "State's Attorney", 2029): 681,
#  ('HONDA CR-V', "State's Attorney", 2030): 549,
#  ('HONDA CR-V', "State's Attorney", 2031): 586,
#  ('HONDA CR-V', "State's Attorney", 2032): 411,
#  ('HONDA CR-V', "State's Attorney", 2033): 488,
#  ('HONDA CR-V', "State's Attorney", 2034): 437,
#  ('HONDA CR-V', "State's Attorney", 2035): 517,
#  ('HONDA CR-V', "State's Attorney", 2036): 581,
#  ('HONDA CR-V', "State's Attorney", 2037): 704,
#  ('HONDA CR-V', 'Housing Services', 2021): 464,
#  ('HONDA CR-V', 'Housing Services', 2022): 601,
#  ('HONDA CR-V', 'Housing Services', 2023): 455,
#  ('HONDA CR-V', 'Housing Services', 2024): 563,
#  ('HONDA CR-V', 'Housing Services', 2025): 632,
#  ('HONDA CR-V', 'Housing Services', 2026): 380,
#  ('HONDA CR-V', 'Housing Services', 2027): 712,
#  ('HONDA CR-V', 'Housing Services', 2028): 550,
#  ('HONDA CR-V', 'Housing Services', 2029): 637,
#  ('HONDA CR-V', 'Housing Services', 2030): 667,
#  ('HONDA CR-V', 'Housing Services', 2031): 625,
#  ('HONDA CR-V', 'Housing Services', 2032): 690,
#  ('HONDA CR-V', 'Housing Services', 2033): 381,
#  ('HONDA CR-V', 'Housing Services', 2034): 702,
#  ('HONDA CR-V', 'Housing Services', 2035): 664,
#  ('HONDA CR-V', 'Housing Services', 2036): 372,
#  ('HONDA CR-V', 'Housing Services', 2037): 568,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2021): 0,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2022): 0,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2023): 0,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2024): 0,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2025): 0,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2026): 0,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2027): 0,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2028): 0,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2029): 0,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2030): 0,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2031): 0,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2032): 0,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2033): 0,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2034): 0,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2035): 0,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2036): 0,
#  ('FORD FUSION HYBRID', 'County Sheriff', 2037): 0,
#  ('FORD FUSION HYBRID', "State's Attorney", 2021): 0,
#  ('FORD FUSION HYBRID', "State's Attorney", 2022): 0,
#  ('FORD FUSION HYBRID', "State's Attorney", 2023): 0,
#  ('FORD FUSION HYBRID', "State's Attorney", 2024): 0,
#  ('FORD FUSION HYBRID', "State's Attorney", 2025): 0,
#  ('FORD FUSION HYBRID', "State's Attorney", 2026): 0,
#  ('FORD FUSION HYBRID', "State's Attorney", 2027): 0,
#  ('FORD FUSION HYBRID', "State's Attorney", 2028): 0,
#  ('FORD FUSION HYBRID', "State's Attorney", 2029): 0,
#  ('FORD FUSION HYBRID', "State's Attorney", 2030): 0,
#  ('FORD FUSION HYBRID', "State's Attorney", 2031): 0,
#  ('FORD FUSION HYBRID', "State's Attorney", 2032): 0,
#  ('FORD FUSION HYBRID', "State's Attorney", 2033): 0,
#  ('FORD FUSION HYBRID', "State's Attorney", 2034): 0,
#  ('FORD FUSION HYBRID', "State's Attorney", 2035): 0,
#  ('FORD FUSION HYBRID', "State's Attorney", 2036): 0,
#  ('FORD FUSION HYBRID', "State's Attorney", 2037): 0,
#  ('FORD FUSION HYBRID', 'Housing Services', 2021): 0,
#  ('FORD FUSION HYBRID', 'Housing Services', 2022): 0,
#  ('FORD FUSION HYBRID', 'Housing Services', 2023): 0,
#  ('FORD FUSION HYBRID', 'Housing Services', 2024): 0,
#  ('FORD FUSION HYBRID', 'Housing Services', 2025): 0,
#  ('FORD FUSION HYBRID', 'Housing Services', 2026): 0,
#  ('FORD FUSION HYBRID', 'Housing Services', 2027): 0,
#  ('FORD FUSION HYBRID', 'Housing Services', 2028): 0,
#  ('FORD FUSION HYBRID', 'Housing Services', 2029): 0,
#  ('FORD FUSION HYBRID', 'Housing Services', 2030): 0,
#  ('FORD FUSION HYBRID', 'Housing Services', 2031): 0,
#  ('FORD FUSION HYBRID', 'Housing Services', 2032): 0,
#  ('FORD FUSION HYBRID', 'Housing Services', 2033): 0,
#  ('FORD FUSION HYBRID', 'Housing Services', 2034): 0,
#  ('FORD FUSION HYBRID', 'Housing Services', 2035): 0,
#  ('FORD FUSION HYBRID', 'Housing Services', 2036): 0,
#  ('FORD FUSION HYBRID', 'Housing Services', 2037): 0,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2021): 0,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2022): 0,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2023): 0,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2024): 0,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2025): 0,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2026): 0,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2027): 0,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2028): 0,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2029): 0,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2030): 0,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2031): 0,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2032): 0,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2033): 0,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2034): 0,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2035): 0,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2036): 0,
#  ('CHRYSLER PACIFICA HYBRID', 'County Sheriff', 2037): 0,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2021): 0,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2022): 0,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2023): 0,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2024): 0,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2025): 0,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2026): 0,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2027): 0,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2028): 0,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2029): 0,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2030): 0,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2031): 0,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2032): 0,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2033): 0,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2034): 0,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2035): 0,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2036): 0,
#  ('CHRYSLER PACIFICA HYBRID', "State's Attorney", 2037): 0,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2021): 0,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2022): 0,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2023): 0,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2024): 0,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2025): 0,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2026): 0,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2027): 0,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2028): 0,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2029): 0,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2030): 0,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2031): 0,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2032): 0,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2033): 0,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2034): 0,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2035): 0,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2036): 0,
#  ('CHRYSLER PACIFICA HYBRID', 'Housing Services', 2037): 0,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2021): 0,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2022): 0,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2023): 0,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2024): 0,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2025): 0,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2026): 0,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2027): 0,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2028): 0,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2029): 0,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2030): 0,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2031): 0,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2032): 0,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2033): 0,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2034): 0,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2035): 0,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2036): 0,
#  ('HONDA CR-V HYBRID', 'County Sheriff', 2037): 0,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2021): 0,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2022): 0,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2023): 0,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2024): 0,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2025): 0,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2026): 0,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2027): 0,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2028): 0,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2029): 0,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2030): 0,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2031): 0,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2032): 0,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2033): 0,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2034): 0,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2035): 0,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2036): 0,
#  ('HONDA CR-V HYBRID', "State's Attorney", 2037): 0,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2021): 0,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2022): 0,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2023): 0,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2024): 0,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2025): 0,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2026): 0,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2027): 0,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2028): 0,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2029): 0,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2030): 0,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2031): 0,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2032): 0,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2033): 0,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2034): 0,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2035): 0,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2036): 0,
#  ('HONDA CR-V HYBRID', 'Housing Services', 2037): 0}

# %%
#random vehicle procurement costs per year
dimensions,P = grb.multidict({(v,t): [np.random.randint(10000,40000)] for v in V for t in T
                  })
P
# Out:
# {('FORD FOCUS', 2021): 18037,
#  ('FORD FOCUS', 2022): 35553,
#  ('FORD FOCUS', 2023): 15039,
#  ('FORD FOCUS', 2024): 21434,
#  ('FORD FOCUS', 2025): 17119,
#  ('FORD FOCUS', 2026): 15017,
#  ('FORD FOCUS', 2027): 19305,
#  ('FORD FOCUS', 2028): 26086,
#  ('FORD FOCUS', 2029): 10771,
#  ('FORD FOCUS', 2030): 23668,
#  ('FORD FOCUS', 2031): 33275,
#  ('FORD FOCUS', 2032): 10707,
#  ('FORD FOCUS', 2033): 32384,
#  ('FORD FOCUS', 2034): 32590,
#  ('FORD FOCUS', 2035): 37260,
#  ('FORD FOCUS', 2036): 36417,
#  ('FORD FOCUS', 2037): 11075,
#  ('DODGE JOURNEY', 2021): 29463,
#  ('DODGE JOURNEY', 2022): 30910,
#  ('DODGE JOURNEY', 2023): 28624,
#  ('DODGE JOURNEY', 2024): 17514,
#  ('DODGE JOURNEY', 2025): 21065,
#  ('DODGE JOURNEY', 2026): 32642,
#  ('DODGE JOURNEY', 2027): 26759,
#  ('DODGE JOURNEY', 2028): 26220,
#  ('DODGE JOURNEY', 2029): 18476,
#  ('DODGE JOURNEY', 2030): 33606,
#  ('DODGE JOURNEY', 2031): 17207,
#  ('DODGE JOURNEY', 2032): 34160,
#  ('DODGE JOURNEY', 2033): 18173,
#  ('DODGE JOURNEY', 2034): 39576,
#  ('DODGE JOURNEY', 2035): 35446,
#  ('DODGE JOURNEY', 2036): 19461,
#  ('DODGE JOURNEY', 2037): 15727,
#  ('HONDA CR-V', 2021): 12756,
#  ('HONDA CR-V', 2022): 13026,
#  ('HONDA CR-V', 2023): 25907,
#  ('HONDA CR-V', 2024): 23048,
#  ('HONDA CR-V', 2025): 19108,
#  ('HONDA CR-V', 2026): 20501,
#  ('HONDA CR-V', 2027): 16605,
#  ('HONDA CR-V', 2028): 30470,
#  ('HONDA CR-V', 2029): 19376,
#  ('HONDA CR-V', 2030): 37518,
#  ('HONDA CR-V', 2031): 22620,
#  ('HONDA CR-V', 2032): 39950,
#  ('HONDA CR-V', 2033): 26432,
#  ('HONDA CR-V', 2034): 13088,
#  ('HONDA CR-V', 2035): 27149,
#  ('HONDA CR-V', 2036): 12173,
#  ('HONDA CR-V', 2037): 19651,
#  ('FORD FUSION HYBRID', 2021): 38004,
#  ('FORD FUSION HYBRID', 2022): 38985,
#  ('FORD FUSION HYBRID', 2023): 20105,
#  ('FORD FUSION HYBRID', 2024): 24828,
#  ('FORD FUSION HYBRID', 2025): 22808,
#  ('FORD FUSION HYBRID', 2026): 39606,
#  ('FORD FUSION HYBRID', 2027): 30474,
#  ('FORD FUSION HYBRID', 2028): 16703,
#  ('FORD FUSION HYBRID', 2029): 14461,
#  ('FORD FUSION HYBRID', 2030): 20619,
#  ('FORD FUSION HYBRID', 2031): 18319,
#  ('FORD FUSION HYBRID', 2032): 18319,
#  ('FORD FUSION HYBRID', 2033): 20366,
#  ('FORD FUSION HYBRID', 2034): 25341,
#  ('FORD FUSION HYBRID', 2035): 24401,
#  ('FORD FUSION HYBRID', 2036): 15419,
#  ('FORD FUSION HYBRID', 2037): 36923,
#  ('CHRYSLER PACIFICA HYBRID', 2021): 29950,
#  ('CHRYSLER PACIFICA HYBRID', 2022): 27082,
#  ('CHRYSLER PACIFICA HYBRID', 2023): 29666,
#  ('CHRYSLER PACIFICA HYBRID', 2024): 21761,
#  ('CHRYSLER PACIFICA HYBRID', 2025): 28521,
#  ('CHRYSLER PACIFICA HYBRID', 2026): 38511,
#  ('CHRYSLER PACIFICA HYBRID', 2027): 35493,
#  ('CHRYSLER PACIFICA HYBRID', 2028): 19219,
#  ('CHRYSLER PACIFICA HYBRID', 2029): 19556,
#  ('CHRYSLER PACIFICA HYBRID', 2030): 28077,
#  ('CHRYSLER PACIFICA HYBRID', 2031): 23626,
#  ('CHRYSLER PACIFICA HYBRID', 2032): 34310,
#  ('CHRYSLER PACIFICA HYBRID', 2033): 16502,
#  ('CHRYSLER PACIFICA HYBRID', 2034): 38355,
#  ('CHRYSLER PACIFICA HYBRID', 2035): 37602,
#  ('CHRYSLER PACIFICA HYBRID', 2036): 32619,
#  ('CHRYSLER PACIFICA HYBRID', 2037): 39904,
#  ('HONDA CR-V HYBRID', 2021): 13117,
#  ('HONDA CR-V HYBRID', 2022): 14102,
#  ('HONDA CR-V HYBRID', 2023): 22957,
#  ('HONDA CR-V HYBRID', 2024): 34674,
#  ('HONDA CR-V HYBRID', 2025): 38102,
#  ('HONDA CR-V HYBRID', 2026): 10950,
#  ('HONDA CR-V HYBRID', 2027): 24418,
#  ('HONDA CR-V HYBRID', 2028): 21702,
#  ('HONDA CR-V HYBRID', 2029): 18431,
#  ('HONDA CR-V HYBRID', 2030): 19340,
#  ('HONDA CR-V HYBRID', 2031): 20278,
#  ('HONDA CR-V HYBRID', 2032): 12774,
#  ('HONDA CR-V HYBRID', 2033): 23711,
#  ('HONDA CR-V HYBRID', 2034): 39360,
#  ('HONDA CR-V HYBRID', 2035): 12994,
#  ('HONDA CR-V HYBRID', 2036): 33949,
#  ('HONDA CR-V HYBRID', 2037): 28367}

# %%
#annual  procurement and maintenance cost per charging station
dimensions,P_s,M_s = grb.multidict({(t): [
                             np.random.randint(20000,40000), #random maintenance cost per vehicle
                             np.random.randint(5000,10000), #random procurement cost per vehicle
                             ] for t in T
                  })

# %%
P_s
# Out:
# {2021: 24492,
#  2022: 21576,
#  2023: 32270,
#  2024: 39402,
#  2025: 38506,
#  2026: 36584,
#  2027: 29582,
#  2028: 27178,
#  2029: 35195,
#  2030: 24729,
#  2031: 24780,
#  2032: 24520,
#  2033: 25361,
#  2034: 35684,
#  2035: 22603,
#  2036: 35240,
#  2037: 21851}

# %%
M_s
# Out:
# {2021: 7983,
#  2022: 6101,
#  2023: 6442,
#  2024: 7809,
#  2025: 8505,
#  2026: 9649,
#  2027: 5995,
#  2028: 6075,
#  2029: 7161,
#  2030: 8235,
#  2031: 6914,
#  2032: 9359,
#  2033: 6319,
#  2034: 8431,
#  2035: 7644,
#  2036: 9831,
#  2037: 8856}

# %%
#! model will probs be infeasible if this number is greater than inventory

#number of vehicles of type v_p that must remain on hand in dpt d in year t due to lack of miles eligibility for replacement
dimensions,N = grb.multidict({(v_p,d,t): [
                             np.random.randint(0,4), 
                             ] for v_p in V_P for d in D for t in T
                  })

N
# Out:
# {('FORD FOCUS', 'County Sheriff', 2021): 2,
#  ('FORD FOCUS', 'County Sheriff', 2022): 0,
#  ('FORD FOCUS', 'County Sheriff', 2023): 1,
#  ('FORD FOCUS', 'County Sheriff', 2024): 3,
#  ('FORD FOCUS', 'County Sheriff', 2025): 3,
#  ('FORD FOCUS', 'County Sheriff', 2026): 1,
#  ('FORD FOCUS', 'County Sheriff', 2027): 1,
#  ('FORD FOCUS', 'County Sheriff', 2028): 0,
#  ('FORD FOCUS', 'County Sheriff', 2029): 0,
#  ('FORD FOCUS', 'County Sheriff', 2030): 1,
#  ('FORD FOCUS', 'County Sheriff', 2031): 2,
#  ('FORD FOCUS', 'County Sheriff', 2032): 2,
#  ('FORD FOCUS', 'County Sheriff', 2033): 0,
#  ('FORD FOCUS', 'County Sheriff', 2034): 3,
#  ('FORD FOCUS', 'County Sheriff', 2035): 3,
#  ('FORD FOCUS', 'County Sheriff', 2036): 3,
#  ('FORD FOCUS', 'County Sheriff', 2037): 0,
#  ('FORD FOCUS', "State's Attorney", 2021): 3,
#  ('FORD FOCUS', "State's Attorney", 2022): 2,
#  ('FORD FOCUS', "State's Attorney", 2023): 3,
#  ('FORD FOCUS', "State's Attorney", 2024): 2,
#  ('FORD FOCUS', "State's Attorney", 2025): 2,
#  ('FORD FOCUS', "State's Attorney", 2026): 2,
#  ('FORD FOCUS', "State's Attorney", 2027): 2,
#  ('FORD FOCUS', "State's Attorney", 2028): 1,
#  ('FORD FOCUS', "State's Attorney", 2029): 1,
#  ('FORD FOCUS', "State's Attorney", 2030): 2,
#  ('FORD FOCUS', "State's Attorney", 2031): 0,
#  ('FORD FOCUS', "State's Attorney", 2032): 3,
#  ('FORD FOCUS', "State's Attorney", 2033): 2,
#  ('FORD FOCUS', "State's Attorney", 2034): 3,
#  ('FORD FOCUS', "State's Attorney", 2035): 3,
#  ('FORD FOCUS', "State's Attorney", 2036): 0,
#  ('FORD FOCUS', "State's Attorney", 2037): 0,
#  ('FORD FOCUS', 'Housing Services', 2021): 2,
#  ('FORD FOCUS', 'Housing Services', 2022): 3,
#  ('FORD FOCUS', 'Housing Services', 2023): 3,
#  ('FORD FOCUS', 'Housing Services', 2024): 2,
#  ('FORD FOCUS', 'Housing Services', 2025): 3,
#  ('FORD FOCUS', 'Housing Services', 2026): 0,
#  ('FORD FOCUS', 'Housing Services', 2027): 1,
#  ('FORD FOCUS', 'Housing Services', 2028): 3,
#  ('FORD FOCUS', 'Housing Services', 2029): 0,
#  ('FORD FOCUS', 'Housing Services', 2030): 3,
#  ('FORD FOCUS', 'Housing Services', 2031): 0,
#  ('FORD FOCUS', 'Housing Services', 2032): 2,
#  ('FORD FOCUS', 'Housing Services', 2033): 0,
#  ('FORD FOCUS', 'Housing Services', 2034): 0,
#  ('FORD FOCUS', 'Housing Services', 2035): 0,
#  ('FORD FOCUS', 'Housing Services', 2036): 1,
#  ('FORD FOCUS', 'Housing Services', 2037): 0,
#  ('DODGE JOURNEY', 'County Sheriff', 2021): 3,
#  ('DODGE JOURNEY', 'County Sheriff', 2022): 2,
#  ('DODGE JOURNEY', 'County Sheriff', 2023): 3,
#  ('DODGE JOURNEY', 'County Sheriff', 2024): 3,
#  ('DODGE JOURNEY', 'County Sheriff', 2025): 0,
#  ('DODGE JOURNEY', 'County Sheriff', 2026): 0,
#  ('DODGE JOURNEY', 'County Sheriff', 2027): 0,
#  ('DODGE JOURNEY', 'County Sheriff', 2028): 0,
#  ('DODGE JOURNEY', 'County Sheriff', 2029): 2,
#  ('DODGE JOURNEY', 'County Sheriff', 2030): 2,
#  ('DODGE JOURNEY', 'County Sheriff', 2031): 3,
#  ('DODGE JOURNEY', 'County Sheriff', 2032): 2,
#  ('DODGE JOURNEY', 'County Sheriff', 2033): 1,
#  ('DODGE JOURNEY', 'County Sheriff', 2034): 3,
#  ('DODGE JOURNEY', 'County Sheriff', 2035): 0,
#  ('DODGE JOURNEY', 'County Sheriff', 2036): 3,
#  ('DODGE JOURNEY', 'County Sheriff', 2037): 0,
#  ('DODGE JOURNEY', "State's Attorney", 2021): 1,
#  ('DODGE JOURNEY', "State's Attorney", 2022): 1,
#  ('DODGE JOURNEY', "State's Attorney", 2023): 1,
#  ('DODGE JOURNEY', "State's Attorney", 2024): 2,
#  ('DODGE JOURNEY', "State's Attorney", 2025): 0,
#  ('DODGE JOURNEY', "State's Attorney", 2026): 2,
#  ('DODGE JOURNEY', "State's Attorney", 2027): 3,
#  ('DODGE JOURNEY', "State's Attorney", 2028): 3,
#  ('DODGE JOURNEY', "State's Attorney", 2029): 1,
#  ('DODGE JOURNEY', "State's Attorney", 2030): 1,
#  ('DODGE JOURNEY', "State's Attorney", 2031): 0,
#  ('DODGE JOURNEY', "State's Attorney", 2032): 2,
#  ('DODGE JOURNEY', "State's Attorney", 2033): 0,
#  ('DODGE JOURNEY', "State's Attorney", 2034): 0,
#  ('DODGE JOURNEY', "State's Attorney", 2035): 3,
#  ('DODGE JOURNEY', "State's Attorney", 2036): 3,
#  ('DODGE JOURNEY', "State's Attorney", 2037): 2,
#  ('DODGE JOURNEY', 'Housing Services', 2021): 2,
#  ('DODGE JOURNEY', 'Housing Services', 2022): 0,
#  ('DODGE JOURNEY', 'Housing Services', 2023): 1,
#  ('DODGE JOURNEY', 'Housing Services', 2024): 0,
#  ('DODGE JOURNEY', 'Housing Services', 2025): 0,
#  ('DODGE JOURNEY', 'Housing Services', 2026): 2,
#  ('DODGE JOURNEY', 'Housing Services', 2027): 1,
#  ('DODGE JOURNEY', 'Housing Services', 2028): 1,
#  ('DODGE JOURNEY', 'Housing Services', 2029): 1,
#  ('DODGE JOURNEY', 'Housing Services', 2030): 1,
#  ('DODGE JOURNEY', 'Housing Services', 2031): 1,
#  ('DODGE JOURNEY', 'Housing Services', 2032): 3,
#  ('DODGE JOURNEY', 'Housing Services', 2033): 2,
#  ('DODGE JOURNEY', 'Housing Services', 2034): 1,
#  ('DODGE JOURNEY', 'Housing Services', 2035): 2,
#  ('DODGE JOURNEY', 'Housing Services', 2036): 3,
#  ('DODGE JOURNEY', 'Housing Services', 2037): 2,
#  ('HONDA CR-V', 'County Sheriff', 2021): 0,
#  ('HONDA CR-V', 'County Sheriff', 2022): 3,
#  ('HONDA CR-V', 'County Sheriff', 2023): 0,
#  ('HONDA CR-V', 'County Sheriff', 2024): 2,
#  ('HONDA CR-V', 'County Sheriff', 2025): 2,
#  ('HONDA CR-V', 'County Sheriff', 2026): 2,
#  ('HONDA CR-V', 'County Sheriff', 2027): 2,
#  ('HONDA CR-V', 'County Sheriff', 2028): 3,
#  ('HONDA CR-V', 'County Sheriff', 2029): 2,
#  ('HONDA CR-V', 'County Sheriff', 2030): 1,
#  ('HONDA CR-V', 'County Sheriff', 2031): 0,
#  ('HONDA CR-V', 'County Sheriff', 2032): 3,
#  ('HONDA CR-V', 'County Sheriff', 2033): 3,
#  ('HONDA CR-V', 'County Sheriff', 2034): 0,
#  ('HONDA CR-V', 'County Sheriff', 2035): 3,
#  ('HONDA CR-V', 'County Sheriff', 2036): 3,
#  ('HONDA CR-V', 'County Sheriff', 2037): 2,
#  ('HONDA CR-V', "State's Attorney", 2021): 3,
#  ('HONDA CR-V', "State's Attorney", 2022): 2,
#  ('HONDA CR-V', "State's Attorney", 2023): 3,
#  ('HONDA CR-V', "State's Attorney", 2024): 0,
#  ('HONDA CR-V', "State's Attorney", 2025): 2,
#  ('HONDA CR-V', "State's Attorney", 2026): 2,
#  ('HONDA CR-V', "State's Attorney", 2027): 3,
#  ('HONDA CR-V', "State's Attorney", 2028): 3,
#  ('HONDA CR-V', "State's Attorney", 2029): 0,
#  ('HONDA CR-V', "State's Attorney", 2030): 3,
#  ('HONDA CR-V', "State's Attorney", 2031): 3,
#  ('HONDA CR-V', "State's Attorney", 2032): 2,
#  ('HONDA CR-V', "State's Attorney", 2033): 1,
#  ('HONDA CR-V', "State's Attorney", 2034): 1,
#  ('HONDA CR-V', "State's Attorney", 2035): 1,
#  ('HONDA CR-V', "State's Attorney", 2036): 2,
#  ('HONDA CR-V', "State's Attorney", 2037): 2,
#  ('HONDA CR-V', 'Housing Services', 2021): 0,
#  ('HONDA CR-V', 'Housing Services', 2022): 3,
#  ('HONDA CR-V', 'Housing Services', 2023): 2,
#  ('HONDA CR-V', 'Housing Services', 2024): 0,
#  ('HONDA CR-V', 'Housing Services', 2025): 0,
#  ('HONDA CR-V', 'Housing Services', 2026): 3,
#  ('HONDA CR-V', 'Housing Services', 2027): 0,
#  ('HONDA CR-V', 'Housing Services', 2028): 3,
#  ('HONDA CR-V', 'Housing Services', 2029): 0,
#  ('HONDA CR-V', 'Housing Services', 2030): 3,
#  ('HONDA CR-V', 'Housing Services', 2031): 0,
#  ('HONDA CR-V', 'Housing Services', 2032): 1,
#  ('HONDA CR-V', 'Housing Services', 2033): 0,
#  ('HONDA CR-V', 'Housing Services', 2034): 0,
#  ('HONDA CR-V', 'Housing Services', 2035): 0,
#  ('HONDA CR-V', 'Housing Services', 2036): 3,
#  ('HONDA CR-V', 'Housing Services', 2037): 1}

# %%
#weight to apply to each objective
w = {'cost':0.01,'emissions':0.99}

# %%
#target emissions number in final year (based on % of baseline)
Q = 0

# %%
#annual budget amount
B = {t:np.random.randint(200000,400000) for t in T}
B
# Out:
# {2021: 250140,
#  2022: 276633,
#  2023: 234984,
#  2024: 207291,
#  2025: 259596,
#  2026: 237412,
#  2027: 260096,
#  2028: 292059,
#  2029: 360256,
#  2030: 275536,
#  2031: 221634,
#  2032: 264384,
#  2033: 203012,
#  2034: 202761,
#  2035: 351257,
#  2036: 396169,
#  2037: 318005}

# %%
#maximum number of veihcles that a single charging station can service
G = 1000

# %%
#whether or not v_pp is a suitable replacement for v_p
R = {('FORD FOCUS', 'FORD FUSION HYBRID'): 1,
     ('FORD FOCUS', 'CHRYSLER PACIFICA HYBRID'): 0,
     ('FORD FOCUS', 'HONDA CR-V HYBRID'): 0,
     ('DODGE JOURNEY', 'FORD FUSION HYBRID'): 0,
     ('DODGE JOURNEY', 'CHRYSLER PACIFICA HYBRID'): 1,
     ('DODGE JOURNEY', 'HONDA CR-V HYBRID'): 0,
     ('HONDA CR-V', 'FORD FUSION HYBRID'): 0,
     ('HONDA CR-V', 'CHRYSLER PACIFICA HYBRID'): 0,
     ('HONDA CR-V', 'HONDA CR-V HYBRID'): 1}

# %% [markdown]
# # Model

# %%
m = grb.Model('CARNET')
# Out:
# Using license file C:\Users\elynch\gurobi.lic
# Academic license - for non-commercial use only

# %% [markdown]
# ## Decision Variables

# %%
#number of vehicles of type v to HAVE ON HAND in dpt d in year t (both ICE and EV)
x = m.addVars(V,D,T,vtype=grb.GRB.INTEGER,name='x')

#number of vehicles of type v to PROCURE in dpt d in year t (both ICE and EV)
y = m.addVars(V,D,T,vtype=grb.GRB.INTEGER,name='y')

#number of charging stations to have in operation in year t
z = m.addVars(T,vtype=grb.GRB.INTEGER,name='z')

#number of charging stations to build in year t
s = m.addVars(T,vtype=grb.GRB.INTEGER,name='s')

#amount over budget in year t
P_B = m.addVars(T,vtype=grb.GRB.CONTINUOUS,name='P_B')

#! may only need for final year
#amount over emissions target in year t
P_E = m.addVars(T,vtype=grb.GRB.CONTINUOUS,name='P_E')

# %% [markdown]
# ## Objective

# %%
obj = m.setObjective(w['cost']*(grb.quicksum((C[v,d,t]+M[v,d,t])*x[v,d,t]+P[v,t]*y[v,d,t] for v in V for d in D for t in T) + (grb.quicksum(M_s[t]*z[t]+P_s[t]*s[t] for t in T))) + #COST
                     w['emissions']*(grb.quicksum(E[v,d,t]*x[v,d,t] for v in V for d in D for t in T)) + #EMISSIONS
                     10000000*grb.quicksum(P_B[t]+P_E[t] for t in T)
                     ,grb.GRB.MINIMIZE)

# %% [markdown]
# ## Constraints

# %% [raw]
# c0 = m.addConstr(x[('FORD FOCUS',
#   'County Sheriff',
#   2023)] == 0)

# %%
#must meet emissions target in the final year (apply penalty if you don't)
c1 = m.addConstr(grb.quicksum(E[v,d,T[-1]]*x[v,d,T[-1]] for v in V for d in D) <= Q + P_E[T[-1]],'meet_emissions_target')

# %%
#!might also be missing procurement cost of stations here as well

#cannot exceed annual budget
c2 = m.addConstrs((grb.quicksum((C[v,d,t]+M[v,d,t])*x[v,d,t]+P[v,t]*y[v,d,t] for v in V for d in D) +
                   M_s[t]*z[t]+P_s[t]*s[t] <= B[t]+P_B[t] for t in T),'stay_under_budget')

# %%
#net number of new vehicles for any dpt between ICE and EV for any dpt and year must be equal to the required inventory of the given vehicle
c3 = m.addConstrs((x[v_p,d,t]+grb.quicksum(R[v_p,v_pp]*x[v_pp,d,t] for v_pp in V_PP) == I[v_p,d] for v_p in V_P for d in D for t in T),'inventory_balancing')

# %%
#! I don't know that we actually need this

#must start first year with current inventory 
c4 = m.addConstrs((x[v,d,T[0]] == I[v,d] for v in V for d in D),'starting_inventory')

# %%
#vehicles can only be replaced once they have driven at least some number of miles (i.e. number of x[vp] has to remain at least at the number of inelligble vehicles)
c5 = m.addConstrs((x[v_p,d,t] >= N[v_p,d,t] for v_p in V_P for d in D for t in T),'cant replace newer vehicles')

# %%
# a certain number of charging stations are required per some number of vehicles
c6 = m.addConstrs((grb.quicksum(s[i] for i in range(T[0],t)) >= grb.quicksum(x[v_pp,d,i] for v_pp in V_PP for d in D for i in range(T[0],t))/G for t in T),'charging_station_Ratio')

# %%
#define the number of vehicles of type v procured in year t for dpt d
c7 = m.addConstrs((x[v_pp,d,t] - x[v_pp,d,t-1] == y[v_pp,d,t] for v_pp in V_PP for d in D for t in T[1:]),'vehicle_procurement_definition')

# %%
#define the number of charging stations built in year t
c8 = m.addConstrs((z[t]-z[t-1] == s[t] for t in T[1:]),'charging_station_development_definition')

# %%
#! I think this needs to be added or else the model won't have any way of knowing how many are in operation

#define the number of charging stations in operation in year t
c9 = None

# %% [markdown]
# ## Solution & Output Analysis

# %%
m.optimize()
# Out:
# Gurobi Optimizer version 9.0.3 build v9.0.3rc0 (win64)
# Optimize a model with 519 rows, 680 columns and 2990 nonzeros
# Model fingerprint: 0x91d27a4f
# Variable types: 34 continuous, 646 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 4e+04]
#   Objective range  [2e+00, 1e+07]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 4e+05]
# Found heuristic solution: objective 3.120495e+12
# Presolve removed 346 rows and 361 columns
# Presolve time: 0.01s
# Presolved: 173 rows, 319 columns, 1655 nonzeros
# Variable types: 0 continuous, 319 integer (0 binary)
#
# Root relaxation: objective 2.148196e+12, 257 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2.1482e+12    0   82 3.1205e+12 2.1482e+12  31.2%     -    0s
# H    0     0                    2.336705e+12 2.1482e+12  8.07%     -    0s
# H    0     0                    2.303215e+12 2.1482e+12  6.73%     -    0s
# H    0     0                    2.246015e+12 2.1486e+12  4.34%     -    0s
#      0     0 2.1802e+12    0   89 2.2460e+12 2.1802e+12  2.93%     -    0s
# H    0     0                    2.236595e+12 2.1802e+12  2.52%     -    0s
# H    0     0                    2.229785e+12 2.1802e+12  2.22%     -    0s
# H    0     0                    2.210855e+12 2.1802e+12  1.38%     -    0s
# H    0     0                    2.208535e+12 2.1802e+12  1.28%     -    0s
#      0     0 2.1827e+12    0  110 2.2085e+12 2.1827e+12  1.17%     -    0s
# H    0     0                    2.201495e+12 2.1827e+12  0.86%     -    0s
#      0     0 2.1837e+12    0   78 2.2015e+12 2.1837e+12  0.81%     -    0s
#      0     0 2.1838e+12    0   79 2.2015e+12 2.1838e+12  0.81%     -    0s
#      0     0 2.1841e+12    0   81 2.2015e+12 2.1841e+12  0.79%     -    0s
# H    0     0                    2.201015e+12 2.1841e+12  0.77%     -    0s
#      0     0 2.1844e+12    0   83 2.2010e+12 2.1844e+12  0.76%     -    0s
#      0     0 2.1844e+12    0   84 2.2010e+12 2.1844e+12  0.76%     -    0s
#      0     0 2.1845e+12    0  124 2.2010e+12 2.1845e+12  0.75%     -    0s
#      0     0 2.1845e+12    0  124 2.2010e+12 2.1845e+12  0.75%     -    0s
# H    0     0                    2.198695e+12 2.1845e+12  0.65%     -    0s
#      0     2 2.1845e+12    0  124 2.1987e+12 2.1845e+12  0.65%     -    0s
# H  887   891                    2.198695e+12 2.1858e+12  0.59%   3.1    0s
# H 1151  1057                    2.197115e+12 2.1860e+12  0.51%   3.3    0s
# H 1323   840                    2.193595e+12 2.1860e+12  0.35%   3.4    0s
# H 1329   788                    2.193595e+12 2.1883e+12  0.24%   3.4    0s
# H 1333   751                    2.193595e+12 2.1887e+12  0.23%   3.4    0s
# H 1335   714                    2.193595e+12 2.1888e+12  0.22%   3.4    1s
# H 1343   684                    2.193595e+12 2.1895e+12  0.18%   3.4    1s
# H 1344   649                    2.193235e+12 2.1896e+12  0.17%   3.4    1s
# H 1349   620                    2.193235e+12 2.1900e+12  0.15%   3.3    1s
# H 1384   615                    2.192015e+12 2.1905e+12  0.07%   3.8    1s
# H 1447   567                    2.192015e+12 2.1909e+12  0.05%   3.9    1s
#
# Cutting planes:
#   Gomory: 1
#   MIR: 78
#
# Explored 2521 nodes (11867 simplex iterations) in 1.67 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 10: 2.19201e+12 2.19201e+12 2.19323e+12 ... 2.19711e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.192014746894e+12, best bound 2.191903734120e+12, gap 0.0051%

# %%
for d in D:
    print()
    print(d)
    print()
    for r in R:
        if R[r]==1:
            v_p = r[0]
            v_pp = r[1]
            print()
            print('        ',v_p,'->',v_pp)
            for t in T:
                print('   ',t,x[v_p,d,t].x,x[v_pp,d,t].x)
# Out:
# County Sheriff
#
#
#          FORD FOCUS -> FORD FUSION HYBRID
#     2021 67.0 0.0
#     2022 67.0 -0.0
#     2023 67.0 0.0
#     2024 67.0 0.0
#     2025 63.0 4.0
#     2026 63.0 4.0
#     2027 63.0 4.0
#     2028 62.0 5.0
#     2029 60.0 7.0
#     2030 54.0 13.0
#     2031 52.0 15.0
#     2032 52.0 15.0
#     2033 52.0 15.0
#     2034 52.0 15.0
#     2035 52.0 15.0
#     2036 52.0 15.0
#     2037 52.0 15.0
#
#          DODGE JOURNEY -> CHRYSLER PACIFICA HYBRID
#     2021 60.0 0.0
#     2022 60.0 -0.0
#     2023 59.0 1.0
#     2024 57.0 3.0
#     2025 56.0 4.0
#     2026 56.0 4.0
#     2027 54.0 6.0
#     2028 47.0 13.0
#     2029 45.0 15.0
#     2030 44.0 16.0
#     2031 42.0 18.0
#     2032 42.0 18.0
#     2033 39.0 21.0
#     2034 39.0 21.0
#     2035 39.0 21.0
#     2036 39.0 21.0
#     2037 35.0 25.0
#
#          HONDA CR-V -> HONDA CR-V HYBRID
#     2021 37.0 0.0
#     2022 37.0 -0.0
#     2023 37.0 0.0
#     2024 37.0 -0.0
#     2025 37.0 0.0
#     2026 36.0 1.0
#     2027 36.0 1.0
#     2028 36.0 1.0
#     2029 36.0 1.0
#     2030 36.0 1.0
#     2031 36.0 1.0
#     2032 27.0 10.0
#     2033 27.0 10.0
#     2034 27.0 10.0
#     2035 20.0 17.0
#     2036 20.0 17.0
#     2037 20.0 17.0
#
# State's Attorney
#
#
#          FORD FOCUS -> FORD FUSION HYBRID
#     2021 40.0 0.0
#     2022 40.0 -0.0
#     2023 40.0 0.0
#     2024 40.0 -0.0
#     2025 40.0 -0.0
#     2026 40.0 0.0
#     2027 40.0 0.0
#     2028 40.0 -0.0
#     2029 40.0 0.0
#     2030 40.0 -0.0
#     2031 40.0 0.0
#     2032 40.0 -0.0
#     2033 40.0 0.0
#     2034 40.0 -0.0
#     2035 40.0 -0.0
#     2036 40.0 0.0
#     2037 40.0 -0.0
#
#          DODGE JOURNEY -> CHRYSLER PACIFICA HYBRID
#     2021 64.0 0.0
#     2022 64.0 -0.0
#     2023 64.0 0.0
#     2024 64.0 0.0
#     2025 64.0 -0.0
#     2026 64.0 0.0
#     2027 64.0 0.0
#     2028 64.0 -0.0
#     2029 64.0 0.0
#     2030 64.0 -0.0
#     2031 64.0 0.0
#     2032 64.0 -0.0
#     2033 64.0 0.0
#     2034 64.0 -0.0
#     2035 64.0 0.0
#     2036 64.0 0.0
#     2037 64.0 -0.0
#
#          HONDA CR-V -> HONDA CR-V HYBRID
#     2021 28.0 0.0
#     2022 19.0 9.0
#     2023 19.0 9.0
#     2024 19.0 9.0
#     2025 19.0 9.0
#     2026 13.0 15.0
#     2027 11.0 17.0
#     2028 11.0 17.0
#     2029 11.0 17.0
#     2030 11.0 17.0
#     2031 11.0 17.0
#     2032 11.0 17.0
#     2033 11.0 17.0
#     2034 11.0 17.0
#     2035 2.0 26.0
#     2036 2.0 26.0
#     2037 2.0 26.0
#
# Housing Services
#
#
#          FORD FOCUS -> FORD FUSION HYBRID
#     2021 35.0 0.0
#     2022 35.0 -0.0
#     2023 31.0 4.0
#     2024 31.0 4.0
#     2025 31.0 4.0
#     2026 31.0 4.0
#     2027 31.0 4.0
#     2028 31.0 4.0
#     2029 20.0 15.0
#     2030 20.0 15.0
#     2031 20.0 15.0
#     2032 20.0 15.0
#     2033 20.0 15.0
#     2034 18.0 17.0
#     2035 18.0 17.0
#     2036 1.0 34.0
#     2037 1.0 34.0
#
#          DODGE JOURNEY -> CHRYSLER PACIFICA HYBRID
#     2021 68.0 0.0
#     2022 68.0 -0.0
#     2023 68.0 0.0
#     2024 68.0 0.0
#     2025 68.0 -0.0
#     2026 68.0 0.0
#     2027 68.0 0.0
#     2028 68.0 -0.0
#     2029 68.0 0.0
#     2030 68.0 0.0
#     2031 68.0 -0.0
#     2032 68.0 0.0
#     2033 68.0 0.0
#     2034 68.0 -0.0
#     2035 68.0 0.0
#     2036 68.0 0.0
#     2037 68.0 -0.0
#
#          HONDA CR-V -> HONDA CR-V HYBRID
#     2021 59.0 0.0
#     2022 59.0 -0.0
#     2023 59.0 0.0
#     2024 59.0 -0.0
#     2025 59.0 0.0
#     2026 59.0 -0.0
#     2027 59.0 0.0
#     2028 59.0 -0.0
#     2029 59.0 0.0
#     2030 59.0 -0.0
#     2031 59.0 0.0
#     2032 59.0 -0.0
#     2033 59.0 0.0
#     2034 59.0 -0.0
#     2035 59.0 -0.0
#     2036 59.0 0.0
#     2037 59.0 -0.0
