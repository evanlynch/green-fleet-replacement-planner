# %%
import gurobipy as grb
import numpy as np

# %% [markdown]
# #### Notes
# - costs could be on a per-mile basis, and then use projected miles to determine an actual annualized cost amount
# - dummy costs are just random numbers for now. Will need to replace with functions that can project out throguh the planning period

# %% [markdown]
# # Data

# %%
#random set of vehicles. v_p (v prime) is the set of ICE vehicles. v_pp (v double prime) is the set of EV alternatives
V_P = ['FORD FOCUS','DODGE JOURNEY','HONDA CR-V']
V_PP = ['FORD FUSION HYBRID','CHRYSLER PACIFICA HYBRID','HONDA CR-V HYBRID']
V = V_P+V_PP

print(f'ICE only: {V_P}')
print(f'EVs: {V_PP}')
print(f'All: {V}')
# Out:
# ICE only: ['FORD FOCUS', 'DODGE JOURNEY', 'HONDA CR-V']
# EVs: ['FORD FUSION HYBRID', 'CHRYSLER PACIFICA HYBRID', 'HONDA CR-V HYBRID']
# All: ['FORD FOCUS', 'DODGE JOURNEY', 'HONDA CR-V', 'FORD FUSION HYBRID', 'CHRYSLER PACIFICA HYBRID', 'HONDA CR-V HYBRID']

# %%
#random set of departments
D = ['Recreation and Parks (Recreation Services)',
     'Parking Enforcement Unit',
     'Department of Aging (Facilities)']
D
# Out:
# ['Recreation and Parks (Recreation Services)',
#  'Parking Enforcement Unit',
#  'Department of Aging (Facilities)']

# %%
#years in the planning horizon
T = [t for t in range(2021,2038)]

# %%
#generate random inventory
I = {}
for d in D:
    for v_p in V_P:
        I[d,v_p] = np.random.randint(20,70)
    for v_pp in V_PP:
        I[d,v_pp] = 0
I
# Out:
# {('Recreation and Parks (Recreation Services)', 'FORD FOCUS'): 22,
#  ('Recreation and Parks (Recreation Services)', 'DODGE JOURNEY'): 38,
#  ('Recreation and Parks (Recreation Services)', 'HONDA CR-V'): 20,
#  ('Recreation and Parks (Recreation Services)', 'FORD FUSION HYBRID'): 0,
#  ('Recreation and Parks (Recreation Services)', 'CHRYSLER PACIFICA HYBRID'): 0,
#  ('Recreation and Parks (Recreation Services)', 'HONDA CR-V HYBRID'): 0,
#  ('Parking Enforcement Unit', 'FORD FOCUS'): 26,
#  ('Parking Enforcement Unit', 'DODGE JOURNEY'): 53,
#  ('Parking Enforcement Unit', 'HONDA CR-V'): 51,
#  ('Parking Enforcement Unit', 'FORD FUSION HYBRID'): 0,
#  ('Parking Enforcement Unit', 'CHRYSLER PACIFICA HYBRID'): 0,
#  ('Parking Enforcement Unit', 'HONDA CR-V HYBRID'): 0,
#  ('Department of Aging (Facilities)', 'FORD FOCUS'): 53,
#  ('Department of Aging (Facilities)', 'DODGE JOURNEY'): 25,
#  ('Department of Aging (Facilities)', 'HONDA CR-V'): 58,
#  ('Department of Aging (Facilities)', 'FORD FUSION HYBRID'): 0,
#  ('Department of Aging (Facilities)', 'CHRYSLER PACIFICA HYBRID'): 0,
#  ('Department of Aging (Facilities)', 'HONDA CR-V HYBRID'): 0}

# %%
#cost factors for consumables (C), maintenance (M), procurement (P), emissions (E)
dimensions,C,M,P,E = grb.multidict({(v,d,t): [np.random.randint(1,4), #random consumables cost per mile 
                             np.random.randint(200,400), #random maintenance cost per vehicle
                             np.random.randint(10000,40000), #random procurement cost per vehicle
                             np.random.randint(1,20),] #random emissions 
                            for v in V for d in D for t in T
                  })
#example consumables. ---I think this could actually just be a projected cost per mile for each vehicle type (based on what type of consumable they use). Then rolled up
C
# Out:
# {('FORD FOCUS', 'Recreation and Parks (Recreation Services)', 2021): 1,
#  ('FORD FOCUS', 'Recreation and Parks (Recreation Services)', 2022): 1,
#  ('FORD FOCUS', 'Recreation and Parks (Recreation Services)', 2023): 1,
#  ('FORD FOCUS', 'Recreation and Parks (Recreation Services)', 2024): 3,
#  ('FORD FOCUS', 'Recreation and Parks (Recreation Services)', 2025): 3,
#  ('FORD FOCUS', 'Recreation and Parks (Recreation Services)', 2026): 2,
#  ('FORD FOCUS', 'Recreation and Parks (Recreation Services)', 2027): 3,
#  ('FORD FOCUS', 'Recreation and Parks (Recreation Services)', 2028): 3,
#  ('FORD FOCUS', 'Recreation and Parks (Recreation Services)', 2029): 2,
#  ('FORD FOCUS', 'Recreation and Parks (Recreation Services)', 2030): 3,
#  ('FORD FOCUS', 'Recreation and Parks (Recreation Services)', 2031): 2,
#  ('FORD FOCUS', 'Recreation and Parks (Recreation Services)', 2032): 1,
#  ('FORD FOCUS', 'Recreation and Parks (Recreation Services)', 2033): 2,
#  ('FORD FOCUS', 'Recreation and Parks (Recreation Services)', 2034): 2,
#  ('FORD FOCUS', 'Recreation and Parks (Recreation Services)', 2035): 3,
#  ('FORD FOCUS', 'Recreation and Parks (Recreation Services)', 2036): 1,
#  ('FORD FOCUS', 'Recreation and Parks (Recreation Services)', 2037): 1,
#  ('FORD FOCUS', 'Parking Enforcement Unit', 2021): 2,
#  ('FORD FOCUS', 'Parking Enforcement Unit', 2022): 3,
#  ('FORD FOCUS', 'Parking Enforcement Unit', 2023): 2,
#  ('FORD FOCUS', 'Parking Enforcement Unit', 2024): 1,
#  ('FORD FOCUS', 'Parking Enforcement Unit', 2025): 2,
#  ('FORD FOCUS', 'Parking Enforcement Unit', 2026): 2,
#  ('FORD FOCUS', 'Parking Enforcement Unit', 2027): 1,
#  ('FORD FOCUS', 'Parking Enforcement Unit', 2028): 1,
#  ('FORD FOCUS', 'Parking Enforcement Unit', 2029): 3,
#  ('FORD FOCUS', 'Parking Enforcement Unit', 2030): 1,
#  ('FORD FOCUS', 'Parking Enforcement Unit', 2031): 2,
#  ('FORD FOCUS', 'Parking Enforcement Unit', 2032): 2,
#  ('FORD FOCUS', 'Parking Enforcement Unit', 2033): 3,
#  ('FORD FOCUS', 'Parking Enforcement Unit', 2034): 3,
#  ('FORD FOCUS', 'Parking Enforcement Unit', 2035): 3,
#  ('FORD FOCUS', 'Parking Enforcement Unit', 2036): 2,
#  ('FORD FOCUS', 'Parking Enforcement Unit', 2037): 3,
#  ('FORD FOCUS', 'Department of Aging (Facilities)', 2021): 3,
#  ('FORD FOCUS', 'Department of Aging (Facilities)', 2022): 3,
#  ('FORD FOCUS', 'Department of Aging (Facilities)', 2023): 2,
#  ('FORD FOCUS', 'Department of Aging (Facilities)', 2024): 1,
#  ('FORD FOCUS', 'Department of Aging (Facilities)', 2025): 2,
#  ('FORD FOCUS', 'Department of Aging (Facilities)', 2026): 3,
#  ('FORD FOCUS', 'Department of Aging (Facilities)', 2027): 1,
#  ('FORD FOCUS', 'Department of Aging (Facilities)', 2028): 3,
#  ('FORD FOCUS', 'Department of Aging (Facilities)', 2029): 3,
#  ('FORD FOCUS', 'Department of Aging (Facilities)', 2030): 3,
#  ('FORD FOCUS', 'Department of Aging (Facilities)', 2031): 3,
#  ('FORD FOCUS', 'Department of Aging (Facilities)', 2032): 1,
#  ('FORD FOCUS', 'Department of Aging (Facilities)', 2033): 1,
#  ('FORD FOCUS', 'Department of Aging (Facilities)', 2034): 2,
#  ('FORD FOCUS', 'Department of Aging (Facilities)', 2035): 3,
#  ('FORD FOCUS', 'Department of Aging (Facilities)', 2036): 1,
#  ('FORD FOCUS', 'Department of Aging (Facilities)', 2037): 2,
#  ('DODGE JOURNEY', 'Recreation and Parks (Recreation Services)', 2021): 2,
#  ('DODGE JOURNEY', 'Recreation and Parks (Recreation Services)', 2022): 1,
#  ('DODGE JOURNEY', 'Recreation and Parks (Recreation Services)', 2023): 3,
#  ('DODGE JOURNEY', 'Recreation and Parks (Recreation Services)', 2024): 2,
#  ('DODGE JOURNEY', 'Recreation and Parks (Recreation Services)', 2025): 1,
#  ('DODGE JOURNEY', 'Recreation and Parks (Recreation Services)', 2026): 1,
#  ('DODGE JOURNEY', 'Recreation and Parks (Recreation Services)', 2027): 2,
#  ('DODGE JOURNEY', 'Recreation and Parks (Recreation Services)', 2028): 1,
#  ('DODGE JOURNEY', 'Recreation and Parks (Recreation Services)', 2029): 2,
#  ('DODGE JOURNEY', 'Recreation and Parks (Recreation Services)', 2030): 1,
#  ('DODGE JOURNEY', 'Recreation and Parks (Recreation Services)', 2031): 3,
#  ('DODGE JOURNEY', 'Recreation and Parks (Recreation Services)', 2032): 2,
#  ('DODGE JOURNEY', 'Recreation and Parks (Recreation Services)', 2033): 3,
#  ('DODGE JOURNEY', 'Recreation and Parks (Recreation Services)', 2034): 2,
#  ('DODGE JOURNEY', 'Recreation and Parks (Recreation Services)', 2035): 1,
#  ('DODGE JOURNEY', 'Recreation and Parks (Recreation Services)', 2036): 3,
#  ('DODGE JOURNEY', 'Recreation and Parks (Recreation Services)', 2037): 1,
#  ('DODGE JOURNEY', 'Parking Enforcement Unit', 2021): 2,
#  ('DODGE JOURNEY', 'Parking Enforcement Unit', 2022): 3,
#  ('DODGE JOURNEY', 'Parking Enforcement Unit', 2023): 2,
#  ('DODGE JOURNEY', 'Parking Enforcement Unit', 2024): 2,
#  ('DODGE JOURNEY', 'Parking Enforcement Unit', 2025): 1,
#  ('DODGE JOURNEY', 'Parking Enforcement Unit', 2026): 1,
#  ('DODGE JOURNEY', 'Parking Enforcement Unit', 2027): 1,
#  ('DODGE JOURNEY', 'Parking Enforcement Unit', 2028): 1,
#  ('DODGE JOURNEY', 'Parking Enforcement Unit', 2029): 1,
#  ('DODGE JOURNEY', 'Parking Enforcement Unit', 2030): 3,
#  ('DODGE JOURNEY', 'Parking Enforcement Unit', 2031): 1,
#  ('DODGE JOURNEY', 'Parking Enforcement Unit', 2032): 2,
#  ('DODGE JOURNEY', 'Parking Enforcement Unit', 2033): 1,
#  ('DODGE JOURNEY', 'Parking Enforcement Unit', 2034): 2,
#  ('DODGE JOURNEY', 'Parking Enforcement Unit', 2035): 3,
#  ('DODGE JOURNEY', 'Parking Enforcement Unit', 2036): 1,
#  ('DODGE JOURNEY', 'Parking Enforcement Unit', 2037): 2,
#  ('DODGE JOURNEY', 'Department of Aging (Facilities)', 2021): 2,
#  ('DODGE JOURNEY', 'Department of Aging (Facilities)', 2022): 2,
#  ('DODGE JOURNEY', 'Department of Aging (Facilities)', 2023): 2,
#  ('DODGE JOURNEY', 'Department of Aging (Facilities)', 2024): 3,
#  ('DODGE JOURNEY', 'Department of Aging (Facilities)', 2025): 3,
#  ('DODGE JOURNEY', 'Department of Aging (Facilities)', 2026): 1,
#  ('DODGE JOURNEY', 'Department of Aging (Facilities)', 2027): 2,
#  ('DODGE JOURNEY', 'Department of Aging (Facilities)', 2028): 2,
#  ('DODGE JOURNEY', 'Department of Aging (Facilities)', 2029): 2,
#  ('DODGE JOURNEY', 'Department of Aging (Facilities)', 2030): 3,
#  ('DODGE JOURNEY', 'Department of Aging (Facilities)', 2031): 3,
#  ('DODGE JOURNEY', 'Department of Aging (Facilities)', 2032): 1,
#  ('DODGE JOURNEY', 'Department of Aging (Facilities)', 2033): 2,
#  ('DODGE JOURNEY', 'Department of Aging (Facilities)', 2034): 1,
#  ('DODGE JOURNEY', 'Department of Aging (Facilities)', 2035): 1,
#  ('DODGE JOURNEY', 'Department of Aging (Facilities)', 2036): 2,
#  ('DODGE JOURNEY', 'Department of Aging (Facilities)', 2037): 3,
#  ('HONDA CR-V', 'Recreation and Parks (Recreation Services)', 2021): 2,
#  ('HONDA CR-V', 'Recreation and Parks (Recreation Services)', 2022): 3,
#  ('HONDA CR-V', 'Recreation and Parks (Recreation Services)', 2023): 2,
#  ('HONDA CR-V', 'Recreation and Parks (Recreation Services)', 2024): 1,
#  ('HONDA CR-V', 'Recreation and Parks (Recreation Services)', 2025): 3,
#  ('HONDA CR-V', 'Recreation and Parks (Recreation Services)', 2026): 2,
#  ('HONDA CR-V', 'Recreation and Parks (Recreation Services)', 2027): 3,
#  ('HONDA CR-V', 'Recreation and Parks (Recreation Services)', 2028): 1,
#  ('HONDA CR-V', 'Recreation and Parks (Recreation Services)', 2029): 1,
#  ('HONDA CR-V', 'Recreation and Parks (Recreation Services)', 2030): 1,
#  ('HONDA CR-V', 'Recreation and Parks (Recreation Services)', 2031): 1,
#  ('HONDA CR-V', 'Recreation and Parks (Recreation Services)', 2032): 2,
#  ('HONDA CR-V', 'Recreation and Parks (Recreation Services)', 2033): 3,
#  ('HONDA CR-V', 'Recreation and Parks (Recreation Services)', 2034): 1,
#  ('HONDA CR-V', 'Recreation and Parks (Recreation Services)', 2035): 1,
#  ('HONDA CR-V', 'Recreation and Parks (Recreation Services)', 2036): 3,
#  ('HONDA CR-V', 'Recreation and Parks (Recreation Services)', 2037): 2,
#  ('HONDA CR-V', 'Parking Enforcement Unit', 2021): 3,
#  ('HONDA CR-V', 'Parking Enforcement Unit', 2022): 2,
#  ('HONDA CR-V', 'Parking Enforcement Unit', 2023): 1,
#  ('HONDA CR-V', 'Parking Enforcement Unit', 2024): 2,
#  ('HONDA CR-V', 'Parking Enforcement Unit', 2025): 1,
#  ('HONDA CR-V', 'Parking Enforcement Unit', 2026): 2,
#  ('HONDA CR-V', 'Parking Enforcement Unit', 2027): 3,
#  ('HONDA CR-V', 'Parking Enforcement Unit', 2028): 2,
#  ('HONDA CR-V', 'Parking Enforcement Unit', 2029): 2,
#  ('HONDA CR-V', 'Parking Enforcement Unit', 2030): 1,
#  ('HONDA CR-V', 'Parking Enforcement Unit', 2031): 2,
#  ('HONDA CR-V', 'Parking Enforcement Unit', 2032): 3,
#  ('HONDA CR-V', 'Parking Enforcement Unit', 2033): 1,
#  ('HONDA CR-V', 'Parking Enforcement Unit', 2034): 2,
#  ('HONDA CR-V', 'Parking Enforcement Unit', 2035): 2,
#  ('HONDA CR-V', 'Parking Enforcement Unit', 2036): 1,
#  ('HONDA CR-V', 'Parking Enforcement Unit', 2037): 1,
#  ('HONDA CR-V', 'Department of Aging (Facilities)', 2021): 1,
#  ('HONDA CR-V', 'Department of Aging (Facilities)', 2022): 1,
#  ('HONDA CR-V', 'Department of Aging (Facilities)', 2023): 1,
#  ('HONDA CR-V', 'Department of Aging (Facilities)', 2024): 2,
#  ('HONDA CR-V', 'Department of Aging (Facilities)', 2025): 1,
#  ('HONDA CR-V', 'Department of Aging (Facilities)', 2026): 1,
#  ('HONDA CR-V', 'Department of Aging (Facilities)', 2027): 3,
#  ('HONDA CR-V', 'Department of Aging (Facilities)', 2028): 3,
#  ('HONDA CR-V', 'Department of Aging (Facilities)', 2029): 3,
#  ('HONDA CR-V', 'Department of Aging (Facilities)', 2030): 1,
#  ('HONDA CR-V', 'Department of Aging (Facilities)', 2031): 3,
#  ('HONDA CR-V', 'Department of Aging (Facilities)', 2032): 3,
#  ('HONDA CR-V', 'Department of Aging (Facilities)', 2033): 1,
#  ('HONDA CR-V', 'Department of Aging (Facilities)', 2034): 3,
#  ('HONDA CR-V', 'Department of Aging (Facilities)', 2035): 1,
#  ('HONDA CR-V', 'Department of Aging (Facilities)', 2036): 3,
#  ('HONDA CR-V', 'Department of Aging (Facilities)', 2037): 1,
#  ('FORD FUSION HYBRID', 'Recreation and Parks (Recreation Services)', 2021): 1,
#  ('FORD FUSION HYBRID', 'Recreation and Parks (Recreation Services)', 2022): 1,
#  ('FORD FUSION HYBRID', 'Recreation and Parks (Recreation Services)', 2023): 1,
#  ('FORD FUSION HYBRID', 'Recreation and Parks (Recreation Services)', 2024): 1,
#  ('FORD FUSION HYBRID', 'Recreation and Parks (Recreation Services)', 2025): 1,
#  ('FORD FUSION HYBRID', 'Recreation and Parks (Recreation Services)', 2026): 3,
#  ('FORD FUSION HYBRID', 'Recreation and Parks (Recreation Services)', 2027): 1,
#  ('FORD FUSION HYBRID', 'Recreation and Parks (Recreation Services)', 2028): 2,
#  ('FORD FUSION HYBRID', 'Recreation and Parks (Recreation Services)', 2029): 2,
#  ('FORD FUSION HYBRID', 'Recreation and Parks (Recreation Services)', 2030): 3,
#  ('FORD FUSION HYBRID', 'Recreation and Parks (Recreation Services)', 2031): 1,
#  ('FORD FUSION HYBRID', 'Recreation and Parks (Recreation Services)', 2032): 2,
#  ('FORD FUSION HYBRID', 'Recreation and Parks (Recreation Services)', 2033): 2,
#  ('FORD FUSION HYBRID', 'Recreation and Parks (Recreation Services)', 2034): 3,
#  ('FORD FUSION HYBRID', 'Recreation and Parks (Recreation Services)', 2035): 2,
#  ('FORD FUSION HYBRID', 'Recreation and Parks (Recreation Services)', 2036): 2,
#  ('FORD FUSION HYBRID', 'Recreation and Parks (Recreation Services)', 2037): 1,
#  ('FORD FUSION HYBRID', 'Parking Enforcement Unit', 2021): 2,
#  ('FORD FUSION HYBRID', 'Parking Enforcement Unit', 2022): 2,
#  ('FORD FUSION HYBRID', 'Parking Enforcement Unit', 2023): 1,
#  ('FORD FUSION HYBRID', 'Parking Enforcement Unit', 2024): 2,
#  ('FORD FUSION HYBRID', 'Parking Enforcement Unit', 2025): 3,
#  ('FORD FUSION HYBRID', 'Parking Enforcement Unit', 2026): 3,
#  ('FORD FUSION HYBRID', 'Parking Enforcement Unit', 2027): 3,
#  ('FORD FUSION HYBRID', 'Parking Enforcement Unit', 2028): 1,
#  ('FORD FUSION HYBRID', 'Parking Enforcement Unit', 2029): 3,
#  ('FORD FUSION HYBRID', 'Parking Enforcement Unit', 2030): 2,
#  ('FORD FUSION HYBRID', 'Parking Enforcement Unit', 2031): 1,
#  ('FORD FUSION HYBRID', 'Parking Enforcement Unit', 2032): 3,
#  ('FORD FUSION HYBRID', 'Parking Enforcement Unit', 2033): 1,
#  ('FORD FUSION HYBRID', 'Parking Enforcement Unit', 2034): 3,
#  ('FORD FUSION HYBRID', 'Parking Enforcement Unit', 2035): 3,
#  ('FORD FUSION HYBRID', 'Parking Enforcement Unit', 2036): 3,
#  ('FORD FUSION HYBRID', 'Parking Enforcement Unit', 2037): 1,
#  ('FORD FUSION HYBRID', 'Department of Aging (Facilities)', 2021): 1,
#  ('FORD FUSION HYBRID', 'Department of Aging (Facilities)', 2022): 1,
#  ('FORD FUSION HYBRID', 'Department of Aging (Facilities)', 2023): 3,
#  ('FORD FUSION HYBRID', 'Department of Aging (Facilities)', 2024): 3,
#  ('FORD FUSION HYBRID', 'Department of Aging (Facilities)', 2025): 1,
#  ('FORD FUSION HYBRID', 'Department of Aging (Facilities)', 2026): 1,
#  ('FORD FUSION HYBRID', 'Department of Aging (Facilities)', 2027): 1,
#  ('FORD FUSION HYBRID', 'Department of Aging (Facilities)', 2028): 2,
#  ('FORD FUSION HYBRID', 'Department of Aging (Facilities)', 2029): 2,
#  ('FORD FUSION HYBRID', 'Department of Aging (Facilities)', 2030): 1,
#  ('FORD FUSION HYBRID', 'Department of Aging (Facilities)', 2031): 1,
#  ('FORD FUSION HYBRID', 'Department of Aging (Facilities)', 2032): 1,
#  ('FORD FUSION HYBRID', 'Department of Aging (Facilities)', 2033): 3,
#  ('FORD FUSION HYBRID', 'Department of Aging (Facilities)', 2034): 2,
#  ('FORD FUSION HYBRID', 'Department of Aging (Facilities)', 2035): 3,
#  ('FORD FUSION HYBRID', 'Department of Aging (Facilities)', 2036): 1,
#  ('FORD FUSION HYBRID', 'Department of Aging (Facilities)', 2037): 2,
#  ('CHRYSLER PACIFICA HYBRID',
#   'Recreation and Parks (Recreation Services)',
#   2021): 3,
#  ('CHRYSLER PACIFICA HYBRID',
#   'Recreation and Parks (Recreation Services)',
#   2022): 1,
#  ('CHRYSLER PACIFICA HYBRID',
#   'Recreation and Parks (Recreation Services)',
#   2023): 3,
#  ('CHRYSLER PACIFICA HYBRID',
#   'Recreation and Parks (Recreation Services)',
#   2024): 2,
#  ('CHRYSLER PACIFICA HYBRID',
#   'Recreation and Parks (Recreation Services)',
#   2025): 1,
#  ('CHRYSLER PACIFICA HYBRID',
#   'Recreation and Parks (Recreation Services)',
#   2026): 3,
#  ('CHRYSLER PACIFICA HYBRID',
#   'Recreation and Parks (Recreation Services)',
#   2027): 2,
#  ('CHRYSLER PACIFICA HYBRID',
#   'Recreation and Parks (Recreation Services)',
#   2028): 2,
#  ('CHRYSLER PACIFICA HYBRID',
#   'Recreation and Parks (Recreation Services)',
#   2029): 1,
#  ('CHRYSLER PACIFICA HYBRID',
#   'Recreation and Parks (Recreation Services)',
#   2030): 1,
#  ('CHRYSLER PACIFICA HYBRID',
#   'Recreation and Parks (Recreation Services)',
#   2031): 2,
#  ('CHRYSLER PACIFICA HYBRID',
#   'Recreation and Parks (Recreation Services)',
#   2032): 3,
#  ('CHRYSLER PACIFICA HYBRID',
#   'Recreation and Parks (Recreation Services)',
#   2033): 1,
#  ('CHRYSLER PACIFICA HYBRID',
#   'Recreation and Parks (Recreation Services)',
#   2034): 2,
#  ('CHRYSLER PACIFICA HYBRID',
#   'Recreation and Parks (Recreation Services)',
#   2035): 2,
#  ('CHRYSLER PACIFICA HYBRID',
#   'Recreation and Parks (Recreation Services)',
#   2036): 1,
#  ('CHRYSLER PACIFICA HYBRID',
#   'Recreation and Parks (Recreation Services)',
#   2037): 2,
#  ('CHRYSLER PACIFICA HYBRID', 'Parking Enforcement Unit', 2021): 3,
#  ('CHRYSLER PACIFICA HYBRID', 'Parking Enforcement Unit', 2022): 1,
#  ('CHRYSLER PACIFICA HYBRID', 'Parking Enforcement Unit', 2023): 1,
#  ('CHRYSLER PACIFICA HYBRID', 'Parking Enforcement Unit', 2024): 3,
#  ('CHRYSLER PACIFICA HYBRID', 'Parking Enforcement Unit', 2025): 3,
#  ('CHRYSLER PACIFICA HYBRID', 'Parking Enforcement Unit', 2026): 1,
#  ('CHRYSLER PACIFICA HYBRID', 'Parking Enforcement Unit', 2027): 1,
#  ('CHRYSLER PACIFICA HYBRID', 'Parking Enforcement Unit', 2028): 3,
#  ('CHRYSLER PACIFICA HYBRID', 'Parking Enforcement Unit', 2029): 1,
#  ('CHRYSLER PACIFICA HYBRID', 'Parking Enforcement Unit', 2030): 3,
#  ('CHRYSLER PACIFICA HYBRID', 'Parking Enforcement Unit', 2031): 2,
#  ('CHRYSLER PACIFICA HYBRID', 'Parking Enforcement Unit', 2032): 3,
#  ('CHRYSLER PACIFICA HYBRID', 'Parking Enforcement Unit', 2033): 2,
#  ('CHRYSLER PACIFICA HYBRID', 'Parking Enforcement Unit', 2034): 3,
#  ('CHRYSLER PACIFICA HYBRID', 'Parking Enforcement Unit', 2035): 3,
#  ('CHRYSLER PACIFICA HYBRID', 'Parking Enforcement Unit', 2036): 3,
#  ('CHRYSLER PACIFICA HYBRID', 'Parking Enforcement Unit', 2037): 2,
#  ('CHRYSLER PACIFICA HYBRID', 'Department of Aging (Facilities)', 2021): 3,
#  ('CHRYSLER PACIFICA HYBRID', 'Department of Aging (Facilities)', 2022): 3,
#  ('CHRYSLER PACIFICA HYBRID', 'Department of Aging (Facilities)', 2023): 1,
#  ('CHRYSLER PACIFICA HYBRID', 'Department of Aging (Facilities)', 2024): 3,
#  ('CHRYSLER PACIFICA HYBRID', 'Department of Aging (Facilities)', 2025): 3,
#  ('CHRYSLER PACIFICA HYBRID', 'Department of Aging (Facilities)', 2026): 1,
#  ('CHRYSLER PACIFICA HYBRID', 'Department of Aging (Facilities)', 2027): 1,
#  ('CHRYSLER PACIFICA HYBRID', 'Department of Aging (Facilities)', 2028): 1,
#  ('CHRYSLER PACIFICA HYBRID', 'Department of Aging (Facilities)', 2029): 1,
#  ('CHRYSLER PACIFICA HYBRID', 'Department of Aging (Facilities)', 2030): 2,
#  ('CHRYSLER PACIFICA HYBRID', 'Department of Aging (Facilities)', 2031): 3,
#  ('CHRYSLER PACIFICA HYBRID', 'Department of Aging (Facilities)', 2032): 3,
#  ('CHRYSLER PACIFICA HYBRID', 'Department of Aging (Facilities)', 2033): 3,
#  ('CHRYSLER PACIFICA HYBRID', 'Department of Aging (Facilities)', 2034): 1,
#  ('CHRYSLER PACIFICA HYBRID', 'Department of Aging (Facilities)', 2035): 3,
#  ('CHRYSLER PACIFICA HYBRID', 'Department of Aging (Facilities)', 2036): 2,
#  ('CHRYSLER PACIFICA HYBRID', 'Department of Aging (Facilities)', 2037): 1,
#  ('HONDA CR-V HYBRID', 'Recreation and Parks (Recreation Services)', 2021): 3,
#  ('HONDA CR-V HYBRID', 'Recreation and Parks (Recreation Services)', 2022): 1,
#  ('HONDA CR-V HYBRID', 'Recreation and Parks (Recreation Services)', 2023): 1,
#  ('HONDA CR-V HYBRID', 'Recreation and Parks (Recreation Services)', 2024): 2,
#  ('HONDA CR-V HYBRID', 'Recreation and Parks (Recreation Services)', 2025): 2,
#  ('HONDA CR-V HYBRID', 'Recreation and Parks (Recreation Services)', 2026): 2,
#  ('HONDA CR-V HYBRID', 'Recreation and Parks (Recreation Services)', 2027): 2,
#  ('HONDA CR-V HYBRID', 'Recreation and Parks (Recreation Services)', 2028): 2,
#  ('HONDA CR-V HYBRID', 'Recreation and Parks (Recreation Services)', 2029): 2,
#  ('HONDA CR-V HYBRID', 'Recreation and Parks (Recreation Services)', 2030): 1,
#  ('HONDA CR-V HYBRID', 'Recreation and Parks (Recreation Services)', 2031): 2,
#  ('HONDA CR-V HYBRID', 'Recreation and Parks (Recreation Services)', 2032): 3,
#  ('HONDA CR-V HYBRID', 'Recreation and Parks (Recreation Services)', 2033): 3,
#  ('HONDA CR-V HYBRID', 'Recreation and Parks (Recreation Services)', 2034): 2,
#  ('HONDA CR-V HYBRID', 'Recreation and Parks (Recreation Services)', 2035): 2,
#  ('HONDA CR-V HYBRID', 'Recreation and Parks (Recreation Services)', 2036): 3,
#  ('HONDA CR-V HYBRID', 'Recreation and Parks (Recreation Services)', 2037): 2,
#  ('HONDA CR-V HYBRID', 'Parking Enforcement Unit', 2021): 3,
#  ('HONDA CR-V HYBRID', 'Parking Enforcement Unit', 2022): 3,
#  ('HONDA CR-V HYBRID', 'Parking Enforcement Unit', 2023): 1,
#  ('HONDA CR-V HYBRID', 'Parking Enforcement Unit', 2024): 1,
#  ('HONDA CR-V HYBRID', 'Parking Enforcement Unit', 2025): 3,
#  ('HONDA CR-V HYBRID', 'Parking Enforcement Unit', 2026): 3,
#  ('HONDA CR-V HYBRID', 'Parking Enforcement Unit', 2027): 2,
#  ('HONDA CR-V HYBRID', 'Parking Enforcement Unit', 2028): 1,
#  ('HONDA CR-V HYBRID', 'Parking Enforcement Unit', 2029): 3,
#  ('HONDA CR-V HYBRID', 'Parking Enforcement Unit', 2030): 3,
#  ('HONDA CR-V HYBRID', 'Parking Enforcement Unit', 2031): 3,
#  ('HONDA CR-V HYBRID', 'Parking Enforcement Unit', 2032): 1,
#  ('HONDA CR-V HYBRID', 'Parking Enforcement Unit', 2033): 2,
#  ('HONDA CR-V HYBRID', 'Parking Enforcement Unit', 2034): 1,
#  ('HONDA CR-V HYBRID', 'Parking Enforcement Unit', 2035): 1,
#  ('HONDA CR-V HYBRID', 'Parking Enforcement Unit', 2036): 3,
#  ('HONDA CR-V HYBRID', 'Parking Enforcement Unit', 2037): 3,
#  ('HONDA CR-V HYBRID', 'Department of Aging (Facilities)', 2021): 1,
#  ('HONDA CR-V HYBRID', 'Department of Aging (Facilities)', 2022): 1,
#  ('HONDA CR-V HYBRID', 'Department of Aging (Facilities)', 2023): 1,
#  ('HONDA CR-V HYBRID', 'Department of Aging (Facilities)', 2024): 2,
#  ('HONDA CR-V HYBRID', 'Department of Aging (Facilities)', 2025): 2,
#  ('HONDA CR-V HYBRID', 'Department of Aging (Facilities)', 2026): 2,
#  ('HONDA CR-V HYBRID', 'Department of Aging (Facilities)', 2027): 1,
#  ('HONDA CR-V HYBRID', 'Department of Aging (Facilities)', 2028): 1,
#  ('HONDA CR-V HYBRID', 'Department of Aging (Facilities)', 2029): 1,
#  ('HONDA CR-V HYBRID', 'Department of Aging (Facilities)', 2030): 2,
#  ('HONDA CR-V HYBRID', 'Department of Aging (Facilities)', 2031): 1,
#  ('HONDA CR-V HYBRID', 'Department of Aging (Facilities)', 2032): 2,
#  ('HONDA CR-V HYBRID', 'Department of Aging (Facilities)', 2033): 2,
#  ('HONDA CR-V HYBRID', 'Department of Aging (Facilities)', 2034): 1,
#  ('HONDA CR-V HYBRID', 'Department of Aging (Facilities)', 2035): 2,
#  ('HONDA CR-V HYBRID', 'Department of Aging (Facilities)', 2036): 2,
#  ('HONDA CR-V HYBRID', 'Department of Aging (Facilities)', 2037): 2}

# %%
#annual  procurement and maintenance cost per charging station
dimensions,P_s,M_s = grb.multidict({(t): [
                             np.random.randint(20000,40000), #random maintenance cost per vehicle
                             np.random.randint(5000,10000), #random procurement cost per vehicle
                             ] for t in T
                  })

P_s
# Out:
# {2021: 25860,
#  2022: 38678,
#  2023: 22194,
#  2024: 26583,
#  2025: 25425,
#  2026: 33832,
#  2027: 36602,
#  2028: 36719,
#  2029: 37522,
#  2030: 20191,
#  2031: 38878,
#  2032: 23569,
#  2033: 32938,
#  2034: 24884,
#  2035: 21629,
#  2036: 34158,
#  2037: 35056}

# %%
#! model will probs be infeasible if this number is greater than inventory

#number of vehicles of type v_p that must remain on hand in dpt d in year t due to lack of miles eligibility for replacement
dimensions,N = grb.multidict({(v_p,d,t): [
                             np.random.randint(0,4), 
                             ] for v_p in V_P for d in D for t in T
                  })

N
# Out:
# {('FORD FOCUS', 'Recreation and Parks (Recreation Services)', 2021): 3,
#  ('FORD FOCUS', 'Recreation and Parks (Recreation Services)', 2022): 1,
#  ('FORD FOCUS', 'Recreation and Parks (Recreation Services)', 2023): 3,
#  ('FORD FOCUS', 'Recreation and Parks (Recreation Services)', 2024): 1,
#  ('FORD FOCUS', 'Recreation and Parks (Recreation Services)', 2025): 0,
#  ('FORD FOCUS', 'Recreation and Parks (Recreation Services)', 2026): 3,
#  ('FORD FOCUS', 'Recreation and Parks (Recreation Services)', 2027): 3,
#  ('FORD FOCUS', 'Recreation and Parks (Recreation Services)', 2028): 1,
#  ('FORD FOCUS', 'Recreation and Parks (Recreation Services)', 2029): 3,
#  ('FORD FOCUS', 'Recreation and Parks (Recreation Services)', 2030): 2,
#  ('FORD FOCUS', 'Recreation and Parks (Recreation Services)', 2031): 2,
#  ('FORD FOCUS', 'Recreation and Parks (Recreation Services)', 2032): 2,
#  ('FORD FOCUS', 'Recreation and Parks (Recreation Services)', 2033): 2,
#  ('FORD FOCUS', 'Recreation and Parks (Recreation Services)', 2034): 3,
#  ('FORD FOCUS', 'Recreation and Parks (Recreation Services)', 2035): 1,
#  ('FORD FOCUS', 'Recreation and Parks (Recreation Services)', 2036): 1,
#  ('FORD FOCUS', 'Recreation and Parks (Recreation Services)', 2037): 3,
#  ('FORD FOCUS', 'Parking Enforcement Unit', 2021): 3,
#  ('FORD FOCUS', 'Parking Enforcement Unit', 2022): 3,
#  ('FORD FOCUS', 'Parking Enforcement Unit', 2023): 3,
#  ('FORD FOCUS', 'Parking Enforcement Unit', 2024): 2,
#  ('FORD FOCUS', 'Parking Enforcement Unit', 2025): 3,
#  ('FORD FOCUS', 'Parking Enforcement Unit', 2026): 2,
#  ('FORD FOCUS', 'Parking Enforcement Unit', 2027): 3,
#  ('FORD FOCUS', 'Parking Enforcement Unit', 2028): 3,
#  ('FORD FOCUS', 'Parking Enforcement Unit', 2029): 1,
#  ('FORD FOCUS', 'Parking Enforcement Unit', 2030): 0,
#  ('FORD FOCUS', 'Parking Enforcement Unit', 2031): 3,
#  ('FORD FOCUS', 'Parking Enforcement Unit', 2032): 3,
#  ('FORD FOCUS', 'Parking Enforcement Unit', 2033): 2,
#  ('FORD FOCUS', 'Parking Enforcement Unit', 2034): 3,
#  ('FORD FOCUS', 'Parking Enforcement Unit', 2035): 1,
#  ('FORD FOCUS', 'Parking Enforcement Unit', 2036): 0,
#  ('FORD FOCUS', 'Parking Enforcement Unit', 2037): 3,
#  ('FORD FOCUS', 'Department of Aging (Facilities)', 2021): 3,
#  ('FORD FOCUS', 'Department of Aging (Facilities)', 2022): 0,
#  ('FORD FOCUS', 'Department of Aging (Facilities)', 2023): 1,
#  ('FORD FOCUS', 'Department of Aging (Facilities)', 2024): 1,
#  ('FORD FOCUS', 'Department of Aging (Facilities)', 2025): 3,
#  ('FORD FOCUS', 'Department of Aging (Facilities)', 2026): 0,
#  ('FORD FOCUS', 'Department of Aging (Facilities)', 2027): 3,
#  ('FORD FOCUS', 'Department of Aging (Facilities)', 2028): 3,
#  ('FORD FOCUS', 'Department of Aging (Facilities)', 2029): 1,
#  ('FORD FOCUS', 'Department of Aging (Facilities)', 2030): 1,
#  ('FORD FOCUS', 'Department of Aging (Facilities)', 2031): 0,
#  ('FORD FOCUS', 'Department of Aging (Facilities)', 2032): 3,
#  ('FORD FOCUS', 'Department of Aging (Facilities)', 2033): 0,
#  ('FORD FOCUS', 'Department of Aging (Facilities)', 2034): 3,
#  ('FORD FOCUS', 'Department of Aging (Facilities)', 2035): 3,
#  ('FORD FOCUS', 'Department of Aging (Facilities)', 2036): 2,
#  ('FORD FOCUS', 'Department of Aging (Facilities)', 2037): 2,
#  ('DODGE JOURNEY', 'Recreation and Parks (Recreation Services)', 2021): 0,
#  ('DODGE JOURNEY', 'Recreation and Parks (Recreation Services)', 2022): 0,
#  ('DODGE JOURNEY', 'Recreation and Parks (Recreation Services)', 2023): 1,
#  ('DODGE JOURNEY', 'Recreation and Parks (Recreation Services)', 2024): 3,
#  ('DODGE JOURNEY', 'Recreation and Parks (Recreation Services)', 2025): 2,
#  ('DODGE JOURNEY', 'Recreation and Parks (Recreation Services)', 2026): 0,
#  ('DODGE JOURNEY', 'Recreation and Parks (Recreation Services)', 2027): 0,
#  ('DODGE JOURNEY', 'Recreation and Parks (Recreation Services)', 2028): 0,
#  ('DODGE JOURNEY', 'Recreation and Parks (Recreation Services)', 2029): 2,
#  ('DODGE JOURNEY', 'Recreation and Parks (Recreation Services)', 2030): 3,
#  ('DODGE JOURNEY', 'Recreation and Parks (Recreation Services)', 2031): 1,
#  ('DODGE JOURNEY', 'Recreation and Parks (Recreation Services)', 2032): 3,
#  ('DODGE JOURNEY', 'Recreation and Parks (Recreation Services)', 2033): 1,
#  ('DODGE JOURNEY', 'Recreation and Parks (Recreation Services)', 2034): 0,
#  ('DODGE JOURNEY', 'Recreation and Parks (Recreation Services)', 2035): 1,
#  ('DODGE JOURNEY', 'Recreation and Parks (Recreation Services)', 2036): 1,
#  ('DODGE JOURNEY', 'Recreation and Parks (Recreation Services)', 2037): 1,
#  ('DODGE JOURNEY', 'Parking Enforcement Unit', 2021): 3,
#  ('DODGE JOURNEY', 'Parking Enforcement Unit', 2022): 0,
#  ('DODGE JOURNEY', 'Parking Enforcement Unit', 2023): 3,
#  ('DODGE JOURNEY', 'Parking Enforcement Unit', 2024): 1,
#  ('DODGE JOURNEY', 'Parking Enforcement Unit', 2025): 3,
#  ('DODGE JOURNEY', 'Parking Enforcement Unit', 2026): 1,
#  ('DODGE JOURNEY', 'Parking Enforcement Unit', 2027): 3,
#  ('DODGE JOURNEY', 'Parking Enforcement Unit', 2028): 2,
#  ('DODGE JOURNEY', 'Parking Enforcement Unit', 2029): 1,
#  ('DODGE JOURNEY', 'Parking Enforcement Unit', 2030): 3,
#  ('DODGE JOURNEY', 'Parking Enforcement Unit', 2031): 3,
#  ('DODGE JOURNEY', 'Parking Enforcement Unit', 2032): 2,
#  ('DODGE JOURNEY', 'Parking Enforcement Unit', 2033): 0,
#  ('DODGE JOURNEY', 'Parking Enforcement Unit', 2034): 1,
#  ('DODGE JOURNEY', 'Parking Enforcement Unit', 2035): 1,
#  ('DODGE JOURNEY', 'Parking Enforcement Unit', 2036): 2,
#  ('DODGE JOURNEY', 'Parking Enforcement Unit', 2037): 3,
#  ('DODGE JOURNEY', 'Department of Aging (Facilities)', 2021): 3,
#  ('DODGE JOURNEY', 'Department of Aging (Facilities)', 2022): 3,
#  ('DODGE JOURNEY', 'Department of Aging (Facilities)', 2023): 1,
#  ('DODGE JOURNEY', 'Department of Aging (Facilities)', 2024): 3,
#  ('DODGE JOURNEY', 'Department of Aging (Facilities)', 2025): 0,
#  ('DODGE JOURNEY', 'Department of Aging (Facilities)', 2026): 2,
#  ('DODGE JOURNEY', 'Department of Aging (Facilities)', 2027): 2,
#  ('DODGE JOURNEY', 'Department of Aging (Facilities)', 2028): 3,
#  ('DODGE JOURNEY', 'Department of Aging (Facilities)', 2029): 0,
#  ('DODGE JOURNEY', 'Department of Aging (Facilities)', 2030): 0,
#  ('DODGE JOURNEY', 'Department of Aging (Facilities)', 2031): 2,
#  ('DODGE JOURNEY', 'Department of Aging (Facilities)', 2032): 1,
#  ('DODGE JOURNEY', 'Department of Aging (Facilities)', 2033): 1,
#  ('DODGE JOURNEY', 'Department of Aging (Facilities)', 2034): 2,
#  ('DODGE JOURNEY', 'Department of Aging (Facilities)', 2035): 2,
#  ('DODGE JOURNEY', 'Department of Aging (Facilities)', 2036): 1,
#  ('DODGE JOURNEY', 'Department of Aging (Facilities)', 2037): 2,
#  ('HONDA CR-V', 'Recreation and Parks (Recreation Services)', 2021): 2,
#  ('HONDA CR-V', 'Recreation and Parks (Recreation Services)', 2022): 3,
#  ('HONDA CR-V', 'Recreation and Parks (Recreation Services)', 2023): 2,
#  ('HONDA CR-V', 'Recreation and Parks (Recreation Services)', 2024): 2,
#  ('HONDA CR-V', 'Recreation and Parks (Recreation Services)', 2025): 2,
#  ('HONDA CR-V', 'Recreation and Parks (Recreation Services)', 2026): 3,
#  ('HONDA CR-V', 'Recreation and Parks (Recreation Services)', 2027): 0,
#  ('HONDA CR-V', 'Recreation and Parks (Recreation Services)', 2028): 0,
#  ('HONDA CR-V', 'Recreation and Parks (Recreation Services)', 2029): 1,
#  ('HONDA CR-V', 'Recreation and Parks (Recreation Services)', 2030): 2,
#  ('HONDA CR-V', 'Recreation and Parks (Recreation Services)', 2031): 3,
#  ('HONDA CR-V', 'Recreation and Parks (Recreation Services)', 2032): 1,
#  ('HONDA CR-V', 'Recreation and Parks (Recreation Services)', 2033): 2,
#  ('HONDA CR-V', 'Recreation and Parks (Recreation Services)', 2034): 3,
#  ('HONDA CR-V', 'Recreation and Parks (Recreation Services)', 2035): 3,
#  ('HONDA CR-V', 'Recreation and Parks (Recreation Services)', 2036): 3,
#  ('HONDA CR-V', 'Recreation and Parks (Recreation Services)', 2037): 1,
#  ('HONDA CR-V', 'Parking Enforcement Unit', 2021): 3,
#  ('HONDA CR-V', 'Parking Enforcement Unit', 2022): 1,
#  ('HONDA CR-V', 'Parking Enforcement Unit', 2023): 1,
#  ('HONDA CR-V', 'Parking Enforcement Unit', 2024): 0,
#  ('HONDA CR-V', 'Parking Enforcement Unit', 2025): 0,
#  ('HONDA CR-V', 'Parking Enforcement Unit', 2026): 1,
#  ('HONDA CR-V', 'Parking Enforcement Unit', 2027): 3,
#  ('HONDA CR-V', 'Parking Enforcement Unit', 2028): 2,
#  ('HONDA CR-V', 'Parking Enforcement Unit', 2029): 3,
#  ('HONDA CR-V', 'Parking Enforcement Unit', 2030): 1,
#  ('HONDA CR-V', 'Parking Enforcement Unit', 2031): 3,
#  ('HONDA CR-V', 'Parking Enforcement Unit', 2032): 1,
#  ('HONDA CR-V', 'Parking Enforcement Unit', 2033): 2,
#  ('HONDA CR-V', 'Parking Enforcement Unit', 2034): 1,
#  ('HONDA CR-V', 'Parking Enforcement Unit', 2035): 0,
#  ('HONDA CR-V', 'Parking Enforcement Unit', 2036): 3,
#  ('HONDA CR-V', 'Parking Enforcement Unit', 2037): 0,
#  ('HONDA CR-V', 'Department of Aging (Facilities)', 2021): 1,
#  ('HONDA CR-V', 'Department of Aging (Facilities)', 2022): 3,
#  ('HONDA CR-V', 'Department of Aging (Facilities)', 2023): 1,
#  ('HONDA CR-V', 'Department of Aging (Facilities)', 2024): 1,
#  ('HONDA CR-V', 'Department of Aging (Facilities)', 2025): 0,
#  ('HONDA CR-V', 'Department of Aging (Facilities)', 2026): 1,
#  ('HONDA CR-V', 'Department of Aging (Facilities)', 2027): 2,
#  ('HONDA CR-V', 'Department of Aging (Facilities)', 2028): 2,
#  ('HONDA CR-V', 'Department of Aging (Facilities)', 2029): 0,
#  ('HONDA CR-V', 'Department of Aging (Facilities)', 2030): 1,
#  ('HONDA CR-V', 'Department of Aging (Facilities)', 2031): 0,
#  ('HONDA CR-V', 'Department of Aging (Facilities)', 2032): 2,
#  ('HONDA CR-V', 'Department of Aging (Facilities)', 2033): 2,
#  ('HONDA CR-V', 'Department of Aging (Facilities)', 2034): 2,
#  ('HONDA CR-V', 'Department of Aging (Facilities)', 2035): 2,
#  ('HONDA CR-V', 'Department of Aging (Facilities)', 2036): 2,
#  ('HONDA CR-V', 'Department of Aging (Facilities)', 2037): 2}

# %%
#weight to apply to each objective
w = [0.5,0.5]

# %%
#target emissions number in final year (based on % of baseline)
Q = 3

# %%
#annual budget amount
B = {t:np.random.randint(200000,400000) for t in T}
B
# Out:
# {2021: 304115,
#  2022: 340471,
#  2023: 285302,
#  2024: 222166,
#  2025: 338292,
#  2026: 342157,
#  2027: 376259,
#  2028: 268417,
#  2029: 361534,
#  2030: 203906,
#  2031: 261272,
#  2032: 242582,
#  2033: 331057,
#  2034: 327659,
#  2035: 230808,
#  2036: 225375,
#  2037: 387886}

# %%
#maximum number of veihcles that a single charging station can service
G = 1000

# %%
#whether or not v_pp is a suitable replacement for v_p
R = {('FORD FOCUS', 'FORD FUSION HYBRID'): 1,
     ('FORD FOCUS', 'CHRYSLER PACIFICA HYBRID'): 0,
     ('FORD FOCUS', 'HONDA CR-V HYBRID'): 0,
     ('DODGE JOURNEY', 'FORD FUSION HYBRID'): 0,
     ('DODGE JOURNEY', 'CHRYSLER PACIFICA HYBRID'): 1,
     ('DODGE JOURNEY', 'HONDA CR-V HYBRID'): 0,
     ('HONDA CR-V', 'FORD FUSION HYBRID'): 0,
     ('HONDA CR-V', 'CHRYSLER PACIFICA HYBRID'): 0,
     ('HONDA CR-V', 'HONDA CR-V HYBRID'): 1}

# %% [markdown]
# # Model

# %%
m = grb.Model('CARNET')
# Out:
# Using license file C:\Users\elynch\gurobi.lic
# Academic license - for non-commercial use only

# %% [markdown]
# ## Decision Variables

# %%
#number of vehicles of type v to HAVE ON HAND in dpt d in year t (both ICE and EV)
x = m.addVars(V,D,T,vtype=grb.GRB.INTEGER,name='x')

#number of vehicles of type v to PROCURE in dpt d in year t (both ICE and EV)
y = m.addVars(V,D,T,vtype=grb.GRB.INTEGER,name='y')

#number of charging stations to have in operation in year t
z = m.addVars(T,vtype=grb.GRB.INTEGER,name='z')

#number of charging stations to build in year t
s = m.addVars(T,vtype=grb.GRB.INTEGER,name='s')

#amount over budget in year t
P_B = m.addVars(T,vtype=grb.GRB.CONTINUOUS,name='P_B')

#! may only need for final year
#amount over emissions target in year t
P_B = m.addVars(T,vtype=grb.GRB.CONTINUOUS,name='P_B')

# %% [markdown]
# ## Objective

# %% [markdown]
# ## Constraints

# %% [markdown]
# ## Solution & Output Analysis
